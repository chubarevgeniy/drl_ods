# %%
import torch
from torch import nn 
import numpy as np
import gym
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
import json
# Out:
# Warning: Gym version v0.24.0 has a number of critical issues with `gym.make` such that the `reset` and `step` functions are called before returning the environment. It is recommend to downgrading to v0.23.1 or upgrading to v0.25.1
# C:\Users\boh-b\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\tensorboard\__init__.py:2: DeprecationWarning: The distutils package is deprecated and slated for removal in Python 3.12. Use setuptools or check PEP 632 for potential alternatives
#   from distutils.version import LooseVersion

# %%
class CEM(nn.Module):
    def __init__(self, state_dim, action_dim):
        super().__init__()
        self.device = torch.device('cuda')
        self.state_dim = state_dim
        self.action_dim = action_dim
        
        self.network = nn.Sequential(
            nn.Linear(self.state_dim, 10), 
            nn.ReLU(), 
            nn.Linear(10, self.action_dim)
        )
        #self.network.to(self.device)
        
        self.tanh = nn.Tanh()
        self.optimizer = torch.optim.Adam(self.parameters(), lr=0.1)
        self.loss = nn.L1Loss()
        
    def forward(self, _input):
        #_input = _input.to(self.device)
        return self.network(_input)
    
    def get_action(self, state, exploration=0):
        state = torch.FloatTensor(state)
        #logits = self.forward(state).to('cpu')
        pure_action = self.forward(state).detach().numpy()
        pure_action += exploration*np.random.randn(self.action_dim)
        pure_action = torch.FloatTensor(pure_action)
        action = self.tanh(pure_action).detach().numpy()
        return action
    
    def update_policy(self, elite_trajectories):
        elite_states = []
        elite_actions = []
        for trajectory in elite_trajectories:
            elite_states.extend(trajectory['states'])
            elite_actions.extend(trajectory['actions'])
        elite_states = torch.FloatTensor(np.array(elite_states))
        #elite_states = elite_states.to(self.device)
        elite_actions = torch.FloatTensor(np.array(elite_actions))
        #elite_actions = elite_actions.to(self.device)
        self.optimizer.zero_grad()
        loss = self.loss(self.tanh(self.forward(elite_states)), elite_actions)
        loss.backward()
        self.optimizer.step()
        
#MountainCarContinuous-v0

# %%
def get_trajectory(env, agent, trajectory_len, exploration=0, visualize=False, custom_reward_func = None):
    trajectory = {'states':[], 'actions': [], 'total_reward': 0, 'custom_reward': 0}
    
    state = env.reset()
    trajectory['states'].append(state)
    for i in range(trajectory_len):
        with torch.no_grad():
            action = agent.get_action(state, exploration)
        trajectory['actions'].append(action)
        
        state, reward, done, _ = env.step(action)
        trajectory['total_reward'] += reward
        if custom_reward_func:
            reward = custom_reward_func(state)
            trajectory['custom_reward'] = np.max([trajectory['custom_reward'],reward])
        
        if done:
            break
            
        if visualize:
            env.render()
        
        if(i != trajectory_len-1):
            trajectory['states'].append(state)
    
    if visualize:
        print(i,trajectory['total_reward'])  
    return trajectory

# %%
def get_elite_trajectories(trajectories, q_param, custom_reward_factor = 0, threshold = None):
    total_rewards = [((1-custom_reward_factor)*trajectory['total_reward']+\
                      custom_reward_factor*trajectory['custom_reward']) for trajectory in trajectories]
    quantile = np.quantile(total_rewards, q=q_param)
    if(threshold != None):
        quantile = np.max([threshold,quantile])
    return [trajectory for trajectory in trajectories if (1-custom_reward_factor)*trajectory['total_reward']+\
            custom_reward_factor*trajectory['custom_reward'] > quantile]

def custom_rev(state):
    return np.max([0,state[0]+0.4])

# %%
env = gym.make('MountainCarContinuous-v0')
state_dim = 2
action_dim = 1
writer = SummaryWriter()
learnin_hist = {'mean_reward': [], 
                'exploration': [], 
                'custom_reward_factor': [], 
                'mean_custom_reward': [], 
                'm_merged_reward': []}

agent = CEM(state_dim, action_dim)

# %%
trajectory_len = 1000
q_param = 0.9
exploration = 2
e_rate = 0.98
custom_reward_factor = 0

# %%
episode_n = 200
trajectory_n = 40

for episode in range(0,episode_n):
    trajectories = [get_trajectory(env, agent, trajectory_len, exploration) for _ in range(trajectory_n)]
    
    elite_trajectories = get_elite_trajectories(trajectories, q_param, threshold=50)
    
    #write stat
    mean_total_reward = np.mean([trajectory['total_reward'] for trajectory in trajectories])
    mean_custom_reward = np.mean([trajectory['custom_reward'] for trajectory in trajectories])
    writer.add_scalar('m_total_reward', mean_total_reward, episode)
    writer.add_scalar('m_custom_reward', mean_custom_reward, episode)
    m_merged_reward = (1-custom_reward_factor)*mean_total_reward+\
                      custom_reward_factor*mean_custom_reward
    print()
    writer.add_scalar('m_merged_reward', m_merged_reward, episode)
    print(f'episode: {episode}, mean_total_reward = {mean_total_reward}, mean_custom_reward = {mean_custom_reward}, m_merged_reward = {m_merged_reward}')
    learnin_hist['exploration'].append([episode,exploration])
    learnin_hist['mean_reward'].append([episode,mean_total_reward])
    learnin_hist['custom_reward_factor'].append([episode,custom_reward_factor])
    learnin_hist['m_merged_reward'].append([episode,m_merged_reward])
    learnin_hist['mean_custom_reward'].append([episode,mean_custom_reward])
    
    trajectories = [get_trajectory(env, agent, trajectory_len) for _ in range(trajectory_n//)]
    mean_total_reward = np.mean([trajectory['total_reward'] for trajectory in trajectories])
    writer.add_scalar('validation', mean_total_reward, episode)
    #update
    if len(elite_trajectories) > 0:
        agent.update_policy(elite_trajectories)
    else:
        print('empty train')
      
    exploration = 1 - 1/episode_n
    exploration = 1.5*pow(exploration,0.3)
    #exploration = 0.3*np.abs((rev_factor(episode, 1300, 1700)-0.5))*2
    #custom_reward_factor = rev_factor(episode, 1300, 1700)
# Out:
# episode: 0, mean_total_reward = -2.923208873723013, mean_custom_reward = 0.0, m_merged_reward = -63.27982098510628
# empty train
#
# episode: 1, mean_total_reward = -2.923290462684162, mean_custom_reward = 0.0, m_merged_reward = -39.955903298729964
# empty train
#
# episode: 2, mean_total_reward = -2.924002246791858, mean_custom_reward = 0.0, m_merged_reward = -40.08230473310944
# empty train
#
# episode: 3, mean_total_reward = -2.9244705436901377, mean_custom_reward = 0.0, m_merged_reward = -40.015208604278904
# empty train
#
# episode: 4, mean_total_reward = -2.9234038421562096, mean_custom_reward = 0.0, m_merged_reward = -40.142686577499674
# empty train
#
# episode: 5, mean_total_reward = -2.923259075065623, mean_custom_reward = 0.0, m_merged_reward = -39.925350801597176
# empty train
#
# episode: 6, mean_total_reward = -2.9236164019394666, mean_custom_reward = 0.0, m_merged_reward = -39.61342204763717
# empty train
#
# episode: 7, mean_total_reward = -2.9225932461502273, mean_custom_reward = 0.0, m_merged_reward = -39.80326530479595
# empty train
#
# episode: 8, mean_total_reward = -2.924896110460252, mean_custom_reward = 0.0, m_merged_reward = -39.848146170517346
# empty train
#
# episode: 9, mean_total_reward = -2.922506280793752, mean_custom_reward = 0.0, m_merged_reward = -39.947631536216626
# empty train
#
# episode: 10, mean_total_reward = -2.9256047908470473, mean_custom_reward = 0.0, m_merged_reward = -37.269306251190685
#
# episode: 11, mean_total_reward = -4.403225939823977, mean_custom_reward = 0.0, m_merged_reward = -35.211518108737366
#
# episode: 12, mean_total_reward = -1.0147685353226015, mean_custom_reward = 0.0, m_merged_reward = -23.197993041406704
#
# episode: 13, mean_total_reward = -0.1675817444440572, mean_custom_reward = 0.0, m_merged_reward = -31.875778582519253
#
# episode: 14, mean_total_reward = -0.29687574539305495, mean_custom_reward = 0.0, m_merged_reward = -28.74181914481805
#
# episode: 15, mean_total_reward = -4.758005685580359, mean_custom_reward = 0.0, m_merged_reward = -32.55645720160642
#
# episode: 16, mean_total_reward = -10.67387998920961, mean_custom_reward = 0.0, m_merged_reward = -19.816954111333963
#
# episode: 17, mean_total_reward = -4.681663712543189, mean_custom_reward = 0.0, m_merged_reward = -19.333111852860828
#
# episode: 18, mean_total_reward = -1.1277881863804045, mean_custom_reward = 0.0, m_merged_reward = -18.35433748494193
#
# episode: 19, mean_total_reward = -0.1931957055232309, mean_custom_reward = 0.0, m_merged_reward = -33.94550519905664
#
# episode: 20, mean_total_reward = -0.4215145915200697, mean_custom_reward = 0.0, m_merged_reward = -31.574576399372653
#
# episode: 21, mean_total_reward = -0.4496763165564034, mean_custom_reward = 0.0, m_merged_reward = -39.65421027282601
# empty train
#
# episode: 22, mean_total_reward = -0.41351492941620016, mean_custom_reward = 0.0, m_merged_reward = -36.83888838278341
#
# episode: 23, mean_total_reward = -1.6399836730183268, mean_custom_reward = 0.0, m_merged_reward = -39.72200049879174
# empty train
#
# episode: 24, mean_total_reward = -1.649072952200458, mean_custom_reward = 0.0, m_merged_reward = -39.728753205582606
# empty train
#
# episode: 25, mean_total_reward = -1.6275662766695773, mean_custom_reward = 0.0, m_merged_reward = -39.51417848912778
# empty train
#
# episode: 26, mean_total_reward = -1.6925230736194081, mean_custom_reward = 0.0, m_merged_reward = -39.884139173190356
# empty train
#
# episode: 27, mean_total_reward = -1.6059067803049747, mean_custom_reward = 0.0, m_merged_reward = -39.79547211606945
# empty train
#
# episode: 28, mean_total_reward = -1.6581922805855918, mean_custom_reward = 0.0, m_merged_reward = -39.97646133132447
# empty train
#
# episode: 29, mean_total_reward = -1.7099193686729663, mean_custom_reward = 0.0, m_merged_reward = -39.42222862266899
# empty train
#
# episode: 30, mean_total_reward = -1.7417623436028642, mean_custom_reward = 0.0, m_merged_reward = -37.446158848026506
#
# episode: 31, mean_total_reward = -4.892500316317659, mean_custom_reward = 0.0, m_merged_reward = -40.289284413239
# empty train
#
# episode: 32, mean_total_reward = -5.081107757655403, mean_custom_reward = 0.0, m_merged_reward = -40.398480387543216
# empty train
#
# episode: 33, mean_total_reward = -4.873355159551926, mean_custom_reward = 0.0, m_merged_reward = -40.48713120490484
# empty train
#
# episode: 34, mean_total_reward = -4.954001583388895, mean_custom_reward = 0.0, m_merged_reward = -40.20210957938783
# empty train
#
# episode: 35, mean_total_reward = -5.04810545735306, mean_custom_reward = 0.0, m_merged_reward = -40.37158541475811
# empty train
#
# episode: 36, mean_total_reward = -4.977356161938926, mean_custom_reward = 0.0, m_merged_reward = -40.194187942543486
# empty train
#
# episode: 37, mean_total_reward = -4.937476612469835, mean_custom_reward = 0.0, m_merged_reward = -40.61224040509506
# empty train
#
# episode: 38, mean_total_reward = -4.915665109372736, mean_custom_reward = 0.0, m_merged_reward = -40.518847221495456
# empty train
#
# episode: 39, mean_total_reward = -4.967341386073644, mean_custom_reward = 0.0, m_merged_reward = -40.18561435817632
# empty train
#
# episode: 40, mean_total_reward = -4.954673509708444, mean_custom_reward = 0.0, m_merged_reward = -37.689586013024496
#
# episode: 41, mean_total_reward = -13.634388270004006, mean_custom_reward = 0.0, m_merged_reward = -41.82704592009202
# empty train
#
# episode: 42, mean_total_reward = -13.721966118037983, mean_custom_reward = 0.0, m_merged_reward = -41.90716189762748
# empty train
#
# episode: 43, mean_total_reward = -13.737573816308748, mean_custom_reward = 0.0, m_merged_reward = -42.17089150768952
# empty train
#
# episode: 44, mean_total_reward = -13.723443724316288, mean_custom_reward = 0.0, m_merged_reward = -42.041516593189215
# empty train
#
# episode: 45, mean_total_reward = -13.385468215088897, mean_custom_reward = 0.0, m_merged_reward = -42.12006275458197
# empty train
#
# episode: 46, mean_total_reward = -13.531991244598277, mean_custom_reward = 0.0, m_merged_reward = -41.92187996692341
# empty train
#
# episode: 47, mean_total_reward = -13.69905726785817, mean_custom_reward = 0.0, m_merged_reward = -41.87812108493417
# empty train
#
# episode: 48, mean_total_reward = -13.575601995121414, mean_custom_reward = 0.0, m_merged_reward = -41.896789458374386
# empty train
#
# episode: 49, mean_total_reward = -13.674689365472062, mean_custom_reward = 0.0, m_merged_reward = -41.96962696747787
# empty train
#
# episode: 50, mean_total_reward = -13.643130848610735, mean_custom_reward = 0.0, m_merged_reward = -42.01231042414206
# empty train
#
# episode: 51, mean_total_reward = -13.719524958788014, mean_custom_reward = 0.0, m_merged_reward = -41.87758706347606
# empty train
#
# episode: 52, mean_total_reward = -13.56825109532445, mean_custom_reward = 0.0, m_merged_reward = -41.94559617594443
# empty train
#
# episode: 53, mean_total_reward = -13.644723322781056, mean_custom_reward = 0.0, m_merged_reward = -42.04476837871421
# empty train
#
# episode: 54, mean_total_reward = -13.731474472629605, mean_custom_reward = 0.0, m_merged_reward = -41.94882992990979
# empty train
#
# episode: 55, mean_total_reward = -13.698195547050537, mean_custom_reward = 0.0, m_merged_reward = -42.14422985530256
# empty train
#
# episode: 56, mean_total_reward = -13.687855159355923, mean_custom_reward = 0.0, m_merged_reward = -41.72107953496312
# empty train
#
# episode: 57, mean_total_reward = -13.651989553887791, mean_custom_reward = 0.0, m_merged_reward = -42.22058891451246
# empty train
#
# episode: 58, mean_total_reward = -13.70538628235658, mean_custom_reward = 0.0, m_merged_reward = -42.08609565844004
# empty train
#
# episode: 59, mean_total_reward = -13.70114979426051, mean_custom_reward = 0.0, m_merged_reward = -38.95099168353209
#
# episode: 60, mean_total_reward = -15.852243208120322, mean_custom_reward = 0.0, m_merged_reward = -42.68833631600354
# empty train
#
# episode: 61, mean_total_reward = -15.662269101611901, mean_custom_reward = 0.0, m_merged_reward = -42.25261059899891
# empty train
#
# episode: 62, mean_total_reward = -15.878251941315899, mean_custom_reward = 0.0, m_merged_reward = -42.46025690657454
# empty train
#
# episode: 63, mean_total_reward = -15.717822294340541, mean_custom_reward = 0.0, m_merged_reward = -42.70867901768637
# empty train
#
# episode: 64, mean_total_reward = -15.658996556338627, mean_custom_reward = 0.0, m_merged_reward = -42.47684525302651
# empty train
# episode: 65, mean_total_reward = -15.925597946936955, mean_custom_reward = 0.0, m_merged_reward = -42.142633643986265
# empty train
#
# episode: 66, mean_total_reward = -15.919608741004874, mean_custom_reward = 0.0, m_merged_reward = -42.299281143415286
# empty train
#
# episode: 67, mean_total_reward = -15.873161841602656, mean_custom_reward = 0.0, m_merged_reward = -42.25153588950481
# empty train
#
# episode: 68, mean_total_reward = -15.707653357652447, mean_custom_reward = 0.0, m_merged_reward = -42.12013435448448
# empty train
#
# episode: 69, mean_total_reward = -15.758860647999294, mean_custom_reward = 0.0, m_merged_reward = -42.30853931147402
# empty train
#
# episode: 70, mean_total_reward = -15.6846792061381, mean_custom_reward = 0.0, m_merged_reward = -42.533349024328416
# empty train
#
# episode: 71, mean_total_reward = -15.764550490314978, mean_custom_reward = 0.0, m_merged_reward = -42.0780823159951
# empty train
#
# episode: 72, mean_total_reward = -15.72412472178558, mean_custom_reward = 0.0, m_merged_reward = -42.646402454401326
# empty train
#
# episode: 73, mean_total_reward = -15.752960253102083, mean_custom_reward = 0.0, m_merged_reward = -42.114840067780975
# empty train
#
# episode: 74, mean_total_reward = -15.69015176731077, mean_custom_reward = 0.0, m_merged_reward = -42.679492780065786
# empty train
#
# episode: 75, mean_total_reward = -15.666717153087522, mean_custom_reward = 0.0, m_merged_reward = -42.637657888417074
# empty train
#
# episode: 76, mean_total_reward = -15.79159822399971, mean_custom_reward = 0.0, m_merged_reward = -42.178206873133966
# empty train
#
# episode: 77, mean_total_reward = -15.870029116099811, mean_custom_reward = 0.0, m_merged_reward = -42.46203034925629
# empty train
#
# episode: 78, mean_total_reward = -15.649939683368123, mean_custom_reward = 0.0, m_merged_reward = -42.34417756561743
# empty train
#
# episode: 79, mean_total_reward = -15.754626651851662, mean_custom_reward = 0.0, m_merged_reward = -42.25542713149677
# empty train
#
# episode: 80, mean_total_reward = -15.697722015280197, mean_custom_reward = 0.0, m_merged_reward = -42.37624833774859
# empty train
#
# episode: 81, mean_total_reward = -15.764226074492603, mean_custom_reward = 0.0, m_merged_reward = -42.41160872509384
# empty train
#
# episode: 82, mean_total_reward = -15.824079018394468, mean_custom_reward = 0.0, m_merged_reward = -42.346417959126725
# empty train
#
# episode: 83, mean_total_reward = -15.839419682469321, mean_custom_reward = 0.0, m_merged_reward = -42.27886928309636
# empty train
#
# episode: 84, mean_total_reward = -15.840434004262823, mean_custom_reward = 0.0, m_merged_reward = -42.34598115720809
# empty train
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [81], in <cell line: 4>()
#       2 trajectory_n = 40
#       4 for episode in range(0,episode_n):
# ----> 5     trajectories = [get_trajectory(env, agent, trajectory_len, exploration) for _ in range(trajectory_n)]
#       7     elite_trajectories = get_elite_trajectories(trajectories, q_param, threshold=50)
#       9     #write stat
#
# Input In [81], in <listcomp>(.0)
#       2 trajectory_n = 40
#       4 for episode in range(0,episode_n):
# ----> 5     trajectories = [get_trajectory(env, agent, trajectory_len, exploration) for _ in range(trajectory_n)]
#       7     elite_trajectories = get_elite_trajectories(trajectories, q_param, threshold=50)
#       9     #write stat
#
# Input In [39], in get_trajectory(env, agent, trajectory_len, exploration, visualize, custom_reward_func)
#       6 for i in range(trajectory_len):
#       7     with torch.no_grad():
# ----> 8         action = agent.get_action(state, exploration)
#       9     trajectory['actions'].append(action)
#      11     state, reward, done, _ = env.step(action)
#
# Input In [38], in CEM.get_action(self, state, exploration)
#      24 state = torch.FloatTensor(state)
#      25 #logits = self.forward(state).to('cpu')
# ---> 26 pure_action = self.forward(state).detach().numpy()
#      27 pure_action += exploration*np.random.randn(self.action_dim)
#      28 pure_action = torch.FloatTensor(pure_action)
#
# Input In [38], in CEM.forward(self, _input)
#      19 def forward(self, _input):
#      20     #_input = _input.to(self.device)
# ---> 21     return self.network(_input)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\container.py:139, in Sequential.forward(self, input)
#     137 def forward(self, input):
#     138     for module in self:
# --> 139         input = module(input)
#     140     return input
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\activation.py:98, in ReLU.forward(self, input)
#      97 def forward(self, input: Tensor) -> Tensor:
# ---> 98     return F.relu(input, inplace=self.inplace)
#
# KeyboardInterrupt:

# %%
get_trajectory(env, agent, 1000,visualize=True)
print()
# Out:
# 229 97.15741524025064

# %%
torch.save(agent.state_dict(), 'MountainCarContinuous10_best.model')

# %%
fig = plt.figure(figsize=[14,10])
plt.plot(np.array(learnin_hist['mean_reward'])[:,0],np.array(learnin_hist['mean_reward'])[:,1],label='train')

#plt.plot(np.array(learnin_hist['exploration'])[:,0],np.array(learnin_hist['exploration'])[:,1],label='exploration')
plt.grid(True)
plt.ylim([-50,100])
plt.xlabel('episode number')
plt.ylabel('mean reward')
plt.legend()
plt.savefig('train.png',dpi=300,bbox_inches='tight',facecolor='white')

# %%
np.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 -INF
#
# NameError: name 'INF' is not defined

# %%
# Out:
# False
