# %%
import torch
from torch import nn 
import numpy as np
import gym
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
import json
# Out:
# Warning: Gym version v0.24.0 has a number of critical issues with `gym.make` such that the `reset` and `step` functions are called before returning the environment. It is recommend to downgrading to v0.23.1 or upgrading to v0.25.1
# C:\Users\boh-b\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\tensorboard\__init__.py:2: DeprecationWarning: The distutils package is deprecated and slated for removal in Python 3.12. Use setuptools or check PEP 632 for potential alternatives
#   from distutils.version import LooseVersion

# %%
class CEM(nn.Module):
    def __init__(self, state_dim, action_dim):
        super().__init__()
        self.device = torch.device('cuda')
        self.state_dim = state_dim
        self.action_dim = action_dim
        
        self.network = nn.Sequential(
            nn.Linear(self.state_dim, 10), 
            nn.LeakyReLU(), 
            nn.Linear(10, self.action_dim)
        )
        #self.network.to(self.device)
        
        self.tanh = nn.Tanh()
        self.optimizer = torch.optim.Adam(self.parameters(), lr=0.01)
        self.loss = nn.L1Loss()
        
    def forward(self, _input):
        #_input = _input.to(self.device)
        return self.network(_input)
    
    def get_action(self, state, exploration=0):
        state = torch.FloatTensor(state)
        #logits = self.forward(state).to('cpu')
        pure_action = self.forward(state).detach().numpy()
        #pure_action += exploration*np.random.randn(self.action_dim)
        action = pure_action + exploration*np.random.randn(self.action_dim)
        return np.clip(action,-1,1)
    
    def update_policy(self, elite_trajectories):
        elite_states = []
        elite_actions = []
        for trajectory in elite_trajectories:
            elite_states.extend(trajectory['states'])
            elite_actions.extend(trajectory['actions'])
        elite_states = torch.FloatTensor(np.array(elite_states))
        #elite_states = elite_states.to(self.device)
        elite_actions = torch.FloatTensor(np.array(elite_actions))
        #elite_actions = elite_actions.to(self.device)
        for i in range(15):
            self.optimizer.zero_grad()
            loss = self.loss(self.forward(elite_states), elite_actions)
            loss.backward()
            self.optimizer.step()
        
#MountainCarContinuous-v0

# %%
def get_trajectory(env, agent, trajectory_len, exploration=0, visualize=False, custom_reward_func = None):
    trajectory = {'states':[], 'actions': [], 'total_reward': 0, 'custom_reward': 0}
    
    state = env.reset()
    trajectory['states'].append(state)
    for i in range(trajectory_len):
        with torch.no_grad():
            action = agent.get_action(state, exploration)
        trajectory['actions'].append(action)
        
        state, reward, done, _ = env.step(action)
        trajectory['total_reward'] += reward
        if custom_reward_func:
            reward = custom_reward_func(state) + reward
            trajectory['custom_reward'] = np.max([trajectory['custom_reward'],reward])
        
        if done:
            break
            
        if visualize:
            env.render()
        
        if(i != trajectory_len-1):
            trajectory['states'].append(state)
    
    if visualize:
        print(i,trajectory['total_reward'])  
    return trajectory

# %%
def get_elite_trajectories(trajectories, q_param, custom_reward_factor = 0, threshold = None):
    total_rewards = [((1-custom_reward_factor)*trajectory['total_reward']+\
                      custom_reward_factor*trajectory['custom_reward']) for trajectory in trajectories]
    quantile = np.quantile(total_rewards, q=q_param)
    if(threshold != None):
        quantile = np.max([threshold,quantile])
    return [trajectory for trajectory in trajectories if (1-custom_reward_factor)*trajectory['total_reward']+\
            custom_reward_factor*trajectory['custom_reward'] > quantile]

def custom_rev(state):
    return 100*np.max([0,state[0]+0.4])

# %%
env = gym.make('MountainCarContinuous-v0')
state_dim = 2
action_dim = 1
writer = SummaryWriter()
learnin_hist = {'mean_reward': [], 
                'exploration': [], 
                'custom_reward_factor': [], 
                'mean_custom_reward': [], 
                'm_merged_reward': [],
                'validation': []}

agent = CEM(state_dim, action_dim)

# %%
trajectory_len = 400
q_param = 0.92
exploration = 1.3
e_rate = 0.98
custom_reward_factor = 0
thresh = 50

# %%
episode_n = 300
trajectory_n = 80

for episode in range(0,episode_n):
    trajectories = [get_trajectory(env, agent, trajectory_len, exploration,custom_reward_func = custom_rev) for _ in range(trajectory_n)]
    
    elite_trajectories = get_elite_trajectories(trajectories, q_param, threshold=thresh, custom_reward_factor = custom_reward_factor)
    
    #write stat
    mean_total_reward = np.mean([trajectory['total_reward'] for trajectory in trajectories])
    mean_custom_reward = np.mean([trajectory['custom_reward'] for trajectory in trajectories])
    writer.add_scalar('m_total_reward', mean_total_reward, episode)
    writer.add_scalar('m_custom_reward', mean_custom_reward, episode)
    m_merged_reward = (1-custom_reward_factor)*mean_total_reward+\
                      custom_reward_factor*mean_custom_reward
    print()
    
    writer.add_scalar('m_merged_reward', m_merged_reward, episode)
    print(f'episode: {episode}, mean_total_reward = {mean_total_reward}, mean_custom_reward = {mean_custom_reward}, m_merged_reward = {m_merged_reward}')
    learnin_hist['exploration'].append([episode,exploration])
    learnin_hist['mean_reward'].append([episode,mean_total_reward])
    learnin_hist['custom_reward_factor'].append([episode,custom_reward_factor])
    learnin_hist['m_merged_reward'].append([episode,m_merged_reward])
    learnin_hist['mean_custom_reward'].append([episode,mean_custom_reward])
    trajectories = [get_trajectory(env, agent, trajectory_len) for _ in range(trajectory_n//8)]
    mean_total_reward = np.mean([trajectory['total_reward'] for trajectory in trajectories])
    writer.add_scalar('validation', mean_total_reward, episode)
    learnin_hist['validation'].append([episode,mean_total_reward])
    if mean_total_reward> 75:
        torch.save(agent.state_dict(), f'MountainCarContinuous10_{episode}.model')
    
    #update
    if len(elite_trajectories) > 0:
        agent.update_policy(elite_trajectories)
    else:
        print('empty train')
    if episode == episode_n//2:
        custom_reward_factor = 0
        exploration = 0.1
        thresh = 50
        torch.save(agent.state_dict(), f'MountainCarContinuous10_{episode}.model')
    #exploration = 1 - episode/episode_n
    #exploration = 1*pow(exploration,0.3)
    print(exploration)
    #exploration = 0.3*np.abs((rev_factor(episode, 1300, 1700)-0.5))*2
    #custom_reward_factor = rev_factor(episode, 1300, 1700)
# Out:
# episode: 0, mean_total_reward = -24.519072921779582, mean_custom_reward = 18.955046858096086, m_merged_reward = -24.519072921779582
# empty train
# 1.3
#
# episode: 1, mean_total_reward = -24.603967296225118, mean_custom_reward = 15.495410659846044, m_merged_reward = -24.603967296225118
# empty train
# 1.3
#
# episode: 2, mean_total_reward = -24.45068251148311, mean_custom_reward = 16.60655438711249, m_merged_reward = -24.45068251148311
# empty train
# 1.3
#
# episode: 3, mean_total_reward = -24.31491886746417, mean_custom_reward = 13.951821880868076, m_merged_reward = -24.31491886746417
# empty train
# 1.3
#
# episode: 4, mean_total_reward = -24.45798069119608, mean_custom_reward = 18.02131306308157, m_merged_reward = -24.45798069119608
# empty train
# 1.3
#
# episode: 5, mean_total_reward = -24.61919815804931, mean_custom_reward = 15.914076618916775, m_merged_reward = -24.61919815804931
# empty train
# 1.3
#
# episode: 6, mean_total_reward = -24.51765289461955, mean_custom_reward = 17.2574420777992, m_merged_reward = -24.51765289461955
# empty train
# 1.3
#
# episode: 7, mean_total_reward = -24.518321919157327, mean_custom_reward = 15.53011845658923, m_merged_reward = -24.518321919157327
# empty train
# 1.3
#
# episode: 8, mean_total_reward = -24.55288647082621, mean_custom_reward = 15.726862530452332, m_merged_reward = -24.55288647082621
# empty train
# 1.3
#
# episode: 9, mean_total_reward = -24.527311166889255, mean_custom_reward = 14.389885129636047, m_merged_reward = -24.527311166889255
# empty train
# 1.3
#
# episode: 10, mean_total_reward = -24.505333783275795, mean_custom_reward = 16.80638672301303, m_merged_reward = -24.505333783275795
# empty train
# 1.3
#
# episode: 11, mean_total_reward = -24.603997588304537, mean_custom_reward = 16.77776754089374, m_merged_reward = -24.603997588304537
# empty train
# 1.3
#
# episode: 12, mean_total_reward = -24.522219794650272, mean_custom_reward = 16.749711654408117, m_merged_reward = -24.522219794650272
# empty train
# 1.3
#
# episode: 13, mean_total_reward = -24.59932153234772, mean_custom_reward = 15.99755348028622, m_merged_reward = -24.59932153234772
# empty train
# 1.3
#
# episode: 14, mean_total_reward = -24.530577913812966, mean_custom_reward = 14.28311333751148, m_merged_reward = -24.530577913812966
# empty train
# 1.3
#
# episode: 15, mean_total_reward = -24.51625138129105, mean_custom_reward = 19.440772706659402, m_merged_reward = -24.51625138129105
# empty train
# 1.3
#
# episode: 16, mean_total_reward = -24.571623743921336, mean_custom_reward = 16.086198179144105, m_merged_reward = -24.571623743921336
# empty train
# 1.3
#
# episode: 17, mean_total_reward = -24.550543162624564, mean_custom_reward = 16.47437134096693, m_merged_reward = -24.550543162624564
# empty train
# 1.3
#
# episode: 18, mean_total_reward = -24.530557903138263, mean_custom_reward = 17.70484570750175, m_merged_reward = -24.530557903138263
# empty train
# 1.3
#
# episode: 19, mean_total_reward = -24.493228925087646, mean_custom_reward = 16.896906226740725, m_merged_reward = -24.493228925087646
# empty train
# 1.3
#
# episode: 20, mean_total_reward = -24.64826225231322, mean_custom_reward = 16.799096323179906, m_merged_reward = -24.64826225231322
# empty train
# 1.3
#
# episode: 21, mean_total_reward = -24.60056738392168, mean_custom_reward = 17.0336461565738, m_merged_reward = -24.60056738392168
# empty train
# 1.3
#
# episode: 22, mean_total_reward = -24.670702704032767, mean_custom_reward = 15.41978963261494, m_merged_reward = -24.670702704032767
# empty train
# 1.3
#
# episode: 23, mean_total_reward = -24.653418873906755, mean_custom_reward = 14.336640553468584, m_merged_reward = -24.653418873906755
# empty train
# 1.3
#
# episode: 24, mean_total_reward = -24.636856504133824, mean_custom_reward = 17.032812165920255, m_merged_reward = -24.636856504133824
# empty train
# 1.3
#
# episode: 25, mean_total_reward = -23.18656148739923, mean_custom_reward = 18.08208431065792, m_merged_reward = -23.18656148739923
# 1.3
#
# episode: 26, mean_total_reward = -24.492386565737938, mean_custom_reward = 18.40234240225488, m_merged_reward = -24.492386565737938
# empty train
# 1.3
#
# episode: 27, mean_total_reward = -24.245572885123, mean_custom_reward = 15.689265818430915, m_merged_reward = -24.245572885123
# empty train
# 1.3
#
# episode: 28, mean_total_reward = -24.52475170748348, mean_custom_reward = 17.40968333304026, m_merged_reward = -24.52475170748348
# empty train
# 1.3
#
# episode: 29, mean_total_reward = -24.609299868142834, mean_custom_reward = 16.14967503829089, m_merged_reward = -24.609299868142834
# empty train
# 1.3
#
# episode: 30, mean_total_reward = -24.331085535925517, mean_custom_reward = 14.170391931873173, m_merged_reward = -24.331085535925517
# empty train
# 1.3
#
# episode: 31, mean_total_reward = -24.449656665197704, mean_custom_reward = 18.04844991849196, m_merged_reward = -24.449656665197704
# empty train
# 1.3
#
# episode: 32, mean_total_reward = -24.58366255182286, mean_custom_reward = 17.597293731475936, m_merged_reward = -24.58366255182286
# empty train
# 1.3
#
# episode: 33, mean_total_reward = -24.378896409938143, mean_custom_reward = 14.75360169746204, m_merged_reward = -24.378896409938143
# empty train
# 1.3
#
# episode: 34, mean_total_reward = -23.33755241994983, mean_custom_reward = 19.05725843031797, m_merged_reward = -23.33755241994983
# 1.3
#
# episode: 35, mean_total_reward = -24.474897454043848, mean_custom_reward = 16.249667478788716, m_merged_reward = -24.474897454043848
# empty train
# 1.3
#
# episode: 36, mean_total_reward = -24.66876863632719, mean_custom_reward = 14.919987151850407, m_merged_reward = -24.66876863632719
# empty train
# 1.3
#
# episode: 37, mean_total_reward = -24.454632542628662, mean_custom_reward = 17.73957602683933, m_merged_reward = -24.454632542628662
# empty train
# 1.3
#
# episode: 38, mean_total_reward = -24.482290177746314, mean_custom_reward = 14.701490169139566, m_merged_reward = -24.482290177746314
# empty train
# 1.3
#
# episode: 39, mean_total_reward = -24.465102832472695, mean_custom_reward = 17.37451435172763, m_merged_reward = -24.465102832472695
# empty train
# 1.3
#
# episode: 40, mean_total_reward = -24.590916061876023, mean_custom_reward = 16.65923507971068, m_merged_reward = -24.590916061876023
# empty train
# 1.3
#
# episode: 41, mean_total_reward = -24.69283296281993, mean_custom_reward = 17.317832097686043, m_merged_reward = -24.69283296281993
# empty train
# 1.3
#
# episode: 42, mean_total_reward = -24.55214938183007, mean_custom_reward = 15.029661879243145, m_merged_reward = -24.55214938183007
# empty train
# 1.3
#
# episode: 43, mean_total_reward = -24.40861120153047, mean_custom_reward = 20.192535791536066, m_merged_reward = -24.40861120153047
# empty train
# 1.3
#
# episode: 44, mean_total_reward = -23.146300853497515, mean_custom_reward = 20.878503212508726, m_merged_reward = -23.146300853497515
# 1.3
#
# episode: 45, mean_total_reward = -24.482720134112775, mean_custom_reward = 18.766404388334415, m_merged_reward = -24.482720134112775
# empty train
# 1.3
#
# episode: 46, mean_total_reward = -24.55880110671116, mean_custom_reward = 16.297159545976626, m_merged_reward = -24.55880110671116
# empty train
# 1.3
#
# episode: 47, mean_total_reward = -24.475443550167583, mean_custom_reward = 19.43019182810978, m_merged_reward = -24.475443550167583
# empty train
# 1.3
#
# episode: 48, mean_total_reward = -23.236167178349202, mean_custom_reward = 19.941459806917944, m_merged_reward = -23.236167178349202
# 1.3
#
# episode: 49, mean_total_reward = -24.485255181563634, mean_custom_reward = 17.885574642148583, m_merged_reward = -24.485255181563634
# empty train
# 1.3
#
# episode: 50, mean_total_reward = -24.65322416411538, mean_custom_reward = 20.61986283837871, m_merged_reward = -24.65322416411538
# empty train
# 1.3
#
# episode: 51, mean_total_reward = -24.526970198423705, mean_custom_reward = 19.710451561002742, m_merged_reward = -24.526970198423705
# empty train
# 1.3
#
# episode: 52, mean_total_reward = -24.72075376532586, mean_custom_reward = 20.400553516173886, m_merged_reward = -24.72075376532586
# empty train
# 1.3
#
# episode: 53, mean_total_reward = -23.105922384193512, mean_custom_reward = 22.769721142260515, m_merged_reward = -23.105922384193512
# 1.3
#
# episode: 54, mean_total_reward = -24.71586075727853, mean_custom_reward = 23.77569645819765, m_merged_reward = -24.71586075727853
# empty train
# 1.3
#
# episode: 55, mean_total_reward = -23.553029524203378, mean_custom_reward = 26.33460364287714, m_merged_reward = -23.553029524203378
# 1.3
#
# episode: 56, mean_total_reward = -23.533043346146993, mean_custom_reward = 25.823047245391727, m_merged_reward = -23.533043346146993
# 1.3
#
# episode: 57, mean_total_reward = -19.54056803557175, mean_custom_reward = 37.34803799026456, m_merged_reward = -19.54056803557175
# 1.3
#
# episode: 58, mean_total_reward = -13.104842169964673, mean_custom_reward = 50.47520169108717, m_merged_reward = -13.104842169964673
# 1.3
#
# episode: 59, mean_total_reward = -6.740435668919227, mean_custom_reward = 56.834821183708435, m_merged_reward = -6.740435668919227
# 1.3
#
# episode: 60, mean_total_reward = 5.212085253650775, mean_custom_reward = 81.61909816156844, m_merged_reward = 5.212085253650775
# 1.3
#
# episode: 61, mean_total_reward = 5.3125852182968885, mean_custom_reward = 78.91501365588518, m_merged_reward = 5.3125852182968885
# 1.3
#
# episode: 62, mean_total_reward = 15.677617185999702, mean_custom_reward = 96.82792542974562, m_merged_reward = 15.677617185999702
# 1.3
#
# episode: 63, mean_total_reward = 34.025337533878925, mean_custom_reward = 123.5363753468469, m_merged_reward = 34.025337533878925
# 1.3
#
# episode: 64, mean_total_reward = 39.09502407943887, mean_custom_reward = 133.73259623547472, m_merged_reward = 39.09502407943887
# 1.3
#
# episode: 65, mean_total_reward = 52.889307394421415, mean_custom_reward = 149.57187293577053, m_merged_reward = 52.889307394421415
# 1.3
#
# episode: 66, mean_total_reward = 54.26782661883907, mean_custom_reward = 150.874040442562, m_merged_reward = 54.26782661883907
# 1.3
#
# episode: 67, mean_total_reward = 61.31034610289928, mean_custom_reward = 162.92042661550803, m_merged_reward = 61.31034610289928
# 1.3
#
# episode: 68, mean_total_reward = 66.33383744816281, mean_custom_reward = 167.5173796746745, m_merged_reward = 66.33383744816281
# 1.3
#
# episode: 69, mean_total_reward = 67.71882590895079, mean_custom_reward = 167.60010324620146, m_merged_reward = 67.71882590895079
# 1.3
#
# episode: 70, mean_total_reward = 74.91316825138485, mean_custom_reward = 176.44004730227056, m_merged_reward = 74.91316825138485
# 1.3
#
# episode: 71, mean_total_reward = 73.58808792612827, mean_custom_reward = 173.87008182439877, m_merged_reward = 73.58808792612827
# 1.3
#
# episode: 72, mean_total_reward = 75.92216419492314, mean_custom_reward = 178.52577486050748, m_merged_reward = 75.92216419492314
# 1.3
#
# episode: 73, mean_total_reward = 75.02352662167723, mean_custom_reward = 176.50278155338054, m_merged_reward = 75.02352662167723
# 1.3
#
# episode: 74, mean_total_reward = 74.61738822191221, mean_custom_reward = 174.8690254736874, m_merged_reward = 74.61738822191221
# 1.3
#
# episode: 75, mean_total_reward = 80.51396859358032, mean_custom_reward = 183.26451981364357, m_merged_reward = 80.51396859358032
# 1.3
#
# episode: 76, mean_total_reward = 75.50349970929679, mean_custom_reward = 178.1004642171805, m_merged_reward = 75.50349970929679
# 1.3
#
# episode: 77, mean_total_reward = 80.05500189569848, mean_custom_reward = 183.91409469040946, m_merged_reward = 80.05500189569848
# 1.3
#
# episode: 78, mean_total_reward = 81.30869462975093, mean_custom_reward = 183.1069346628827, m_merged_reward = 81.30869462975093
# 1.3
#
# episode: 79, mean_total_reward = 79.95484392237788, mean_custom_reward = 182.51040206900566, m_merged_reward = 79.95484392237788
# 1.3
#
# episode: 80, mean_total_reward = 78.42357789662225, mean_custom_reward = 179.33691060118593, m_merged_reward = 78.42357789662225
# 1.3
#
# episode: 81, mean_total_reward = 76.098671967044, mean_custom_reward = 179.26027694003005, m_merged_reward = 76.098671967044
# 1.3
#
# episode: 82, mean_total_reward = 74.91341389749604, mean_custom_reward = 177.24228400332672, m_merged_reward = 74.91341389749604
# 1.3
#
# episode: 83, mean_total_reward = 78.9521039749204, mean_custom_reward = 182.6268867754506, m_merged_reward = 78.9521039749204
# 1.3
#
# episode: 84, mean_total_reward = 81.623046251377, mean_custom_reward = 184.73086625520773, m_merged_reward = 81.623046251377
# 1.3
#
# episode: 85, mean_total_reward = 77.71162288034303, mean_custom_reward = 180.28130154932333, m_merged_reward = 77.71162288034303
# 1.3
#
# episode: 86, mean_total_reward = 79.35202938628302, mean_custom_reward = 181.30634682496634, m_merged_reward = 79.35202938628302
# 1.3
#
# episode: 87, mean_total_reward = 83.13331197106034, mean_custom_reward = 185.37979611635808, m_merged_reward = 83.13331197106034
# 1.3
#
# episode: 88, mean_total_reward = 80.75218935133799, mean_custom_reward = 182.87864866479845, m_merged_reward = 80.75218935133799
# 1.3
#
# episode: 89, mean_total_reward = 75.61328291433601, mean_custom_reward = 177.26046183099496, m_merged_reward = 75.61328291433601
# 1.3
#
# episode: 90, mean_total_reward = 80.13658768576117, mean_custom_reward = 181.46937659820304, m_merged_reward = 80.13658768576117
# 1.3
#
# episode: 91, mean_total_reward = 82.60618601352223, mean_custom_reward = 185.1428168471154, m_merged_reward = 82.60618601352223
# 1.3
#
# episode: 92, mean_total_reward = 84.12328673443326, mean_custom_reward = 186.82862733840244, m_merged_reward = 84.12328673443326
# 1.3
#
# episode: 93, mean_total_reward = 79.78710545494553, mean_custom_reward = 181.2136325112728, m_merged_reward = 79.78710545494553
# 1.3
#
# episode: 94, mean_total_reward = 78.2583529608235, mean_custom_reward = 179.59150987470485, m_merged_reward = 78.2583529608235
# 1.3
#
# episode: 95, mean_total_reward = 82.82147731332638, mean_custom_reward = 184.94227343267198, m_merged_reward = 82.82147731332638
# 1.3
#
# episode: 96, mean_total_reward = 74.05018089598192, mean_custom_reward = 174.86276518572498, m_merged_reward = 74.05018089598192
# 1.3
#
# episode: 97, mean_total_reward = 78.87502754784478, mean_custom_reward = 182.3208936068492, m_merged_reward = 78.87502754784478
# 1.3
#
# episode: 98, mean_total_reward = 79.18634391363068, mean_custom_reward = 181.93003749948485, m_merged_reward = 79.18634391363068
# 1.3
#
# episode: 99, mean_total_reward = 78.36152925479693, mean_custom_reward = 179.0926170678303, m_merged_reward = 78.36152925479693
# 1.3
#
# episode: 100, mean_total_reward = 78.98146157336143, mean_custom_reward = 181.70544707849916, m_merged_reward = 78.98146157336143
# 1.3
#
# episode: 101, mean_total_reward = 80.43614836920226, mean_custom_reward = 181.7454626405835, m_merged_reward = 80.43614836920226
# 1.3
#
# episode: 102, mean_total_reward = 84.06451893706554, mean_custom_reward = 186.86636687483693, m_merged_reward = 84.06451893706554
# 1.3
#
# episode: 103, mean_total_reward = 83.07818256131803, mean_custom_reward = 184.66091787462906, m_merged_reward = 83.07818256131803
# 1.3
#
# episode: 104, mean_total_reward = 81.47936798681896, mean_custom_reward = 183.01659823898103, m_merged_reward = 81.47936798681896
# 1.3
#
# episode: 105, mean_total_reward = 83.24627163581968, mean_custom_reward = 186.88842968522616, m_merged_reward = 83.24627163581968
# 1.3
#
# episode: 106, mean_total_reward = 82.07121962481492, mean_custom_reward = 183.09817495171654, m_merged_reward = 82.07121962481492
# 1.3
#
# episode: 107, mean_total_reward = 73.95359749351778, mean_custom_reward = 174.73218742883176, m_merged_reward = 73.95359749351778
# 1.3
#
# episode: 108, mean_total_reward = 80.38261656785903, mean_custom_reward = 181.9359317569096, m_merged_reward = 80.38261656785903
# 1.3
#
# episode: 109, mean_total_reward = 82.33017300906741, mean_custom_reward = 184.09499988385735, m_merged_reward = 82.33017300906741
# 1.3
#
# episode: 110, mean_total_reward = 82.71969573949302, mean_custom_reward = 184.2113099037248, m_merged_reward = 82.71969573949302
# 1.3
#
# episode: 111, mean_total_reward = 84.24689546572996, mean_custom_reward = 186.7592344778488, m_merged_reward = 84.24689546572996
# 1.3
#
# episode: 112, mean_total_reward = 78.46905338049393, mean_custom_reward = 180.04119546039823, m_merged_reward = 78.46905338049393
# 1.3
#
# episode: 113, mean_total_reward = 79.29058460026756, mean_custom_reward = 179.68218947902568, m_merged_reward = 79.29058460026756
# 1.3
#
# episode: 114, mean_total_reward = 80.21697221567106, mean_custom_reward = 181.32920488213577, m_merged_reward = 80.21697221567106
# 1.3
#
# episode: 115, mean_total_reward = 83.671205575577, mean_custom_reward = 184.9827595633772, m_merged_reward = 83.671205575577
# 1.3
#
# episode: 116, mean_total_reward = 82.91143230511071, mean_custom_reward = 185.00942590279197, m_merged_reward = 82.91143230511071
# 1.3
#
# episode: 117, mean_total_reward = 79.91652977997384, mean_custom_reward = 181.77840074686227, m_merged_reward = 79.91652977997384
# 1.3
# episode: 118, mean_total_reward = 83.2414687824944, mean_custom_reward = 185.24947922254032, m_merged_reward = 83.2414687824944
# 1.3
#
# episode: 119, mean_total_reward = 79.87864215918502, mean_custom_reward = 181.68609490684966, m_merged_reward = 79.87864215918502
# 1.3
#
# episode: 120, mean_total_reward = 78.7949585324643, mean_custom_reward = 181.99630791376165, m_merged_reward = 78.7949585324643
# 1.3
#
# episode: 121, mean_total_reward = 75.20585473948596, mean_custom_reward = 177.6747822005807, m_merged_reward = 75.20585473948596
# 1.3
#
# episode: 122, mean_total_reward = 80.78933342289203, mean_custom_reward = 183.63876815064023, m_merged_reward = 80.78933342289203
# 1.3
#
# episode: 123, mean_total_reward = 79.05935030412958, mean_custom_reward = 181.46568029557739, m_merged_reward = 79.05935030412958
# 1.3
#
# episode: 124, mean_total_reward = 76.00351595265727, mean_custom_reward = 179.14156830790662, m_merged_reward = 76.00351595265727
# 1.3
#
# episode: 125, mean_total_reward = 79.67395249814743, mean_custom_reward = 182.17445226031364, m_merged_reward = 79.67395249814743
# 1.3
#
# episode: 126, mean_total_reward = 80.23549560898917, mean_custom_reward = 181.9289389846035, m_merged_reward = 80.23549560898917
# 1.3
#
# episode: 127, mean_total_reward = 70.8643229579714, mean_custom_reward = 173.09350016271918, m_merged_reward = 70.8643229579714
# 1.3
#
# episode: 128, mean_total_reward = 81.31817149910724, mean_custom_reward = 183.55334673378493, m_merged_reward = 81.31817149910724
# 1.3
#
# episode: 129, mean_total_reward = 76.93578503355602, mean_custom_reward = 178.1163889930343, m_merged_reward = 76.93578503355602
# 1.3
#
# episode: 130, mean_total_reward = 83.07033468543287, mean_custom_reward = 184.26498257774702, m_merged_reward = 83.07033468543287
# 1.3
#
# episode: 131, mean_total_reward = 79.82056917095707, mean_custom_reward = 181.66575536984115, m_merged_reward = 79.82056917095707
# 1.3
#
# episode: 132, mean_total_reward = 84.17986725141094, mean_custom_reward = 186.54567878202664, m_merged_reward = 84.17986725141094
# 1.3
#
# episode: 133, mean_total_reward = 78.21012579655539, mean_custom_reward = 180.66961621954596, m_merged_reward = 78.21012579655539
# 1.3
#
# episode: 134, mean_total_reward = 79.28850726033274, mean_custom_reward = 180.3327782408098, m_merged_reward = 79.28850726033274
# 1.3
#
# episode: 135, mean_total_reward = 81.59175769786223, mean_custom_reward = 183.80587977619774, m_merged_reward = 81.59175769786223
# 1.3
#
# episode: 136, mean_total_reward = 84.38361107011455, mean_custom_reward = 186.8600167471169, m_merged_reward = 84.38361107011455
# 1.3
#
# episode: 137, mean_total_reward = 80.3504843322733, mean_custom_reward = 182.31699446737125, m_merged_reward = 80.3504843322733
# 1.3
#
# episode: 138, mean_total_reward = 84.61780109109444, mean_custom_reward = 186.63176100510523, m_merged_reward = 84.61780109109444
# 1.3
#
# episode: 139, mean_total_reward = 78.48251666065934, mean_custom_reward = 179.9213140070242, m_merged_reward = 78.48251666065934
# 1.3
#
# episode: 140, mean_total_reward = 83.27260853473149, mean_custom_reward = 185.13078804893195, m_merged_reward = 83.27260853473149
# 1.3
#
# episode: 141, mean_total_reward = 81.66987938784538, mean_custom_reward = 183.05616011140967, m_merged_reward = 81.66987938784538
# 1.3
#
# episode: 142, mean_total_reward = 81.80066329335592, mean_custom_reward = 182.4585875567488, m_merged_reward = 81.80066329335592
# 1.3
#
# episode: 143, mean_total_reward = 82.17804928630534, mean_custom_reward = 183.53740828670612, m_merged_reward = 82.17804928630534
# 1.3
#
# episode: 144, mean_total_reward = 81.70913331039068, mean_custom_reward = 182.93277776109508, m_merged_reward = 81.70913331039068
# 1.3
#
# episode: 145, mean_total_reward = 80.91218007074818, mean_custom_reward = 183.6597067976681, m_merged_reward = 80.91218007074818
# 1.3
#
# episode: 146, mean_total_reward = 81.47450002009938, mean_custom_reward = 183.1376507741543, m_merged_reward = 81.47450002009938
# 1.3
#
# episode: 147, mean_total_reward = 84.30241648368633, mean_custom_reward = 186.56983579023168, m_merged_reward = 84.30241648368633
# 1.3
#
# episode: 148, mean_total_reward = 81.00469929276336, mean_custom_reward = 183.28887343334844, m_merged_reward = 81.00469929276336
# 1.3
#
# episode: 149, mean_total_reward = 84.58901234013676, mean_custom_reward = 186.67844740257758, m_merged_reward = 84.58901234013676
# 1.3
#
# episode: 150, mean_total_reward = 81.23344359195073, mean_custom_reward = 183.08883731005804, m_merged_reward = 81.23344359195073
# 0.1
#
# episode: 151, mean_total_reward = 94.32123346150021, mean_custom_reward = 186.866337449586, m_merged_reward = 94.32123346150021
# 0.1
#
# episode: 152, mean_total_reward = 94.63126841588597, mean_custom_reward = 187.53232464595143, m_merged_reward = 94.63126841588597
# 0.1
#
# episode: 153, mean_total_reward = 94.3067423205203, mean_custom_reward = 187.05726332575532, m_merged_reward = 94.3067423205203
# 0.1
#
# episode: 154, mean_total_reward = 94.51110944562711, mean_custom_reward = 186.9535631641551, m_merged_reward = 94.51110944562711
# 0.1
#
# episode: 155, mean_total_reward = 94.17837265540781, mean_custom_reward = 187.7332192748941, m_merged_reward = 94.17837265540781
# 0.1
#
# episode: 156, mean_total_reward = 94.37708960551637, mean_custom_reward = 187.83015297987356, m_merged_reward = 94.37708960551637
# 0.1
#
# episode: 157, mean_total_reward = 93.93549579150434, mean_custom_reward = 187.80183329666858, m_merged_reward = 93.93549579150434
# 0.1
#
# episode: 158, mean_total_reward = 94.19436043140338, mean_custom_reward = 187.55785132670266, m_merged_reward = 94.19436043140338
# 0.1
#
# episode: 159, mean_total_reward = 94.52027196503484, mean_custom_reward = 187.87852148152118, m_merged_reward = 94.52027196503484
# 0.1
#
# episode: 160, mean_total_reward = 94.27674666868056, mean_custom_reward = 188.61551393672787, m_merged_reward = 94.27674666868056
# 0.1
#
# episode: 161, mean_total_reward = 94.32209172974578, mean_custom_reward = 188.86337205522315, m_merged_reward = 94.32209172974578
# 0.1
#
# episode: 162, mean_total_reward = 94.36979540578778, mean_custom_reward = 188.5964135701675, m_merged_reward = 94.36979540578778
# 0.1
#
# episode: 163, mean_total_reward = 94.35998411250975, mean_custom_reward = 188.5761944769917, m_merged_reward = 94.35998411250975
# 0.1
#
# episode: 164, mean_total_reward = 94.5955576392091, mean_custom_reward = 188.24921550925438, m_merged_reward = 94.5955576392091
# 0.1
#
# episode: 165, mean_total_reward = 94.41783251780967, mean_custom_reward = 187.90970161681165, m_merged_reward = 94.41783251780967
# 0.1
#
# episode: 166, mean_total_reward = 94.14427281967968, mean_custom_reward = 188.30812184693127, m_merged_reward = 94.14427281967968
# 0.1
#
# episode: 167, mean_total_reward = 94.75559574242777, mean_custom_reward = 187.87364421552178, m_merged_reward = 94.75559574242777
# 0.1
#
# episode: 168, mean_total_reward = 94.4007401723675, mean_custom_reward = 188.23611133388948, m_merged_reward = 94.4007401723675
# 0.1
#
# episode: 169, mean_total_reward = 94.3581435979506, mean_custom_reward = 188.4514618722369, m_merged_reward = 94.3581435979506
# 0.1
#
# episode: 170, mean_total_reward = 94.57577574500996, mean_custom_reward = 188.21132999403284, m_merged_reward = 94.57577574500996
# 0.1
#
# episode: 171, mean_total_reward = 94.21164969942943, mean_custom_reward = 188.3476508985985, m_merged_reward = 94.21164969942943
# 0.1
#
# episode: 172, mean_total_reward = 94.41333081717661, mean_custom_reward = 188.17783768703566, m_merged_reward = 94.41333081717661
# 0.1
#
# episode: 173, mean_total_reward = 94.75595926775425, mean_custom_reward = 187.86071101501892, m_merged_reward = 94.75595926775425
# 0.1
#
# episode: 174, mean_total_reward = 94.3836984301063, mean_custom_reward = 188.89402085196053, m_merged_reward = 94.3836984301063
# 0.1
#
# episode: 175, mean_total_reward = 94.61909561779711, mean_custom_reward = 188.08175360872542, m_merged_reward = 94.61909561779711
# 0.1
#
# episode: 176, mean_total_reward = 94.3872051087553, mean_custom_reward = 188.365103543732, m_merged_reward = 94.3872051087553
# 0.1
#
# episode: 177, mean_total_reward = 93.0157997153384, mean_custom_reward = 186.79920241766732, m_merged_reward = 93.0157997153384
# 0.1
#
# episode: 178, mean_total_reward = 94.30882893661892, mean_custom_reward = 188.90607306552118, m_merged_reward = 94.30882893661892
# 0.1
# episode: 179, mean_total_reward = 94.6405064566906, mean_custom_reward = 188.38485670293895, m_merged_reward = 94.6405064566906
# 0.1
#
# episode: 180, mean_total_reward = 94.65870609903683, mean_custom_reward = 188.25927468353854, m_merged_reward = 94.65870609903683
# 0.1
#
# episode: 181, mean_total_reward = 94.54930113385166, mean_custom_reward = 187.91203386013905, m_merged_reward = 94.54930113385166
# 0.1
#
# episode: 182, mean_total_reward = 94.75248162007318, mean_custom_reward = 187.49862326671132, m_merged_reward = 94.75248162007318
# 0.1
#
# episode: 183, mean_total_reward = 94.59291693960435, mean_custom_reward = 187.65380678880965, m_merged_reward = 94.59291693960435
# 0.1
#
# episode: 184, mean_total_reward = 94.68517050718546, mean_custom_reward = 187.05376902272843, m_merged_reward = 94.68517050718546
# 0.1
#
# episode: 185, mean_total_reward = 94.60691738920065, mean_custom_reward = 187.0395911879935, m_merged_reward = 94.60691738920065
# 0.1
#
# episode: 186, mean_total_reward = 94.79389535085929, mean_custom_reward = 187.85406640859892, m_merged_reward = 94.79389535085929
# 0.1
#
# episode: 187, mean_total_reward = 94.84768605151332, mean_custom_reward = 188.176978879152, m_merged_reward = 94.84768605151332
# 0.1
#
# episode: 188, mean_total_reward = 94.76965791250642, mean_custom_reward = 187.83910973581115, m_merged_reward = 94.76965791250642
# 0.1
#
# episode: 189, mean_total_reward = 94.88121136175103, mean_custom_reward = 187.70378964663672, m_merged_reward = 94.88121136175103
# 0.1
#
# episode: 190, mean_total_reward = 94.77753449527458, mean_custom_reward = 188.10251230696932, m_merged_reward = 94.77753449527458
# 0.1
#
# episode: 191, mean_total_reward = 94.84864456613835, mean_custom_reward = 187.9267861925417, m_merged_reward = 94.84864456613835
# 0.1
#
# episode: 192, mean_total_reward = 94.95803539042099, mean_custom_reward = 187.4517315599109, m_merged_reward = 94.95803539042099
# 0.1
#
# episode: 193, mean_total_reward = 94.90723848000945, mean_custom_reward = 187.3976914074717, m_merged_reward = 94.90723848000945
# 0.1
#
# episode: 194, mean_total_reward = 95.11210114932074, mean_custom_reward = 186.9624250109802, m_merged_reward = 95.11210114932074
# 0.1
#
# episode: 195, mean_total_reward = 95.0011026985341, mean_custom_reward = 188.06458022379866, m_merged_reward = 95.0011026985341
# 0.1
#
# episode: 196, mean_total_reward = 95.29837729704937, mean_custom_reward = 187.82379569279016, m_merged_reward = 95.29837729704937
# 0.1
#
# episode: 197, mean_total_reward = 95.27522318456036, mean_custom_reward = 187.73392591254574, m_merged_reward = 95.27522318456036
# 0.1
#
# episode: 198, mean_total_reward = 95.18439400447598, mean_custom_reward = 187.81345570550525, m_merged_reward = 95.18439400447598
# 0.1
#
# episode: 199, mean_total_reward = 95.47617532472043, mean_custom_reward = 187.70442611200025, m_merged_reward = 95.47617532472043
# 0.1
#
# episode: 200, mean_total_reward = 94.03260025341203, mean_custom_reward = 186.20592313213427, m_merged_reward = 94.03260025341203
# 0.1
#
# episode: 201, mean_total_reward = 94.18535895008043, mean_custom_reward = 184.8569223641176, m_merged_reward = 94.18535895008043
# 0.1
#
# episode: 202, mean_total_reward = 95.18439598153674, mean_custom_reward = 187.16720427290687, m_merged_reward = 95.18439598153674
# 0.1
#
# episode: 203, mean_total_reward = 94.12871465340666, mean_custom_reward = 185.82054679464622, m_merged_reward = 94.12871465340666
# 0.1
#
# episode: 204, mean_total_reward = 95.46269377960218, mean_custom_reward = 187.57569084550994, m_merged_reward = 95.46269377960218
# 0.1
#
# episode: 205, mean_total_reward = 94.28078818618754, mean_custom_reward = 185.40355993551594, m_merged_reward = 94.28078818618754
# 0.1
#
# episode: 206, mean_total_reward = 95.34580122672345, mean_custom_reward = 187.56496781518308, m_merged_reward = 95.34580122672345
# 0.1
#
# episode: 207, mean_total_reward = 95.59177979393442, mean_custom_reward = 187.56708453639368, m_merged_reward = 95.59177979393442
# 0.1
#
# episode: 208, mean_total_reward = 95.50178466471945, mean_custom_reward = 187.16933509391848, m_merged_reward = 95.50178466471945
# 0.1
#
# episode: 209, mean_total_reward = 95.46829181092536, mean_custom_reward = 187.03196009829816, m_merged_reward = 95.46829181092536
# 0.1
#
# episode: 210, mean_total_reward = 94.4352881241979, mean_custom_reward = 185.21568960260578, m_merged_reward = 94.4352881241979
# 0.1
#
# episode: 211, mean_total_reward = 95.52244716471571, mean_custom_reward = 187.83439916485173, m_merged_reward = 95.52244716471571
# 0.1
#
# episode: 212, mean_total_reward = 95.52393234577355, mean_custom_reward = 187.73183578372064, m_merged_reward = 95.52393234577355
# 0.1
#
# episode: 213, mean_total_reward = 95.57118854792634, mean_custom_reward = 187.4198464250151, m_merged_reward = 95.57118854792634
# 0.1
#
# episode: 214, mean_total_reward = 95.6495711889296, mean_custom_reward = 187.30906107464062, m_merged_reward = 95.6495711889296
# 0.1
#
# episode: 215, mean_total_reward = 94.29193052181083, mean_custom_reward = 185.9710897796399, m_merged_reward = 94.29193052181083
# 0.1
#
# episode: 216, mean_total_reward = 92.99178714521697, mean_custom_reward = 184.05849187796258, m_merged_reward = 92.99178714521697
# 0.1
#
# episode: 217, mean_total_reward = 95.56874033212753, mean_custom_reward = 187.50529525519434, m_merged_reward = 95.56874033212753
# 0.1
#
# episode: 218, mean_total_reward = 94.1652075837035, mean_custom_reward = 186.36105978535858, m_merged_reward = 94.1652075837035
# 0.1
#
# episode: 219, mean_total_reward = 94.2609195964208, mean_custom_reward = 185.01188701187374, m_merged_reward = 94.2609195964208
# 0.1
#
# episode: 220, mean_total_reward = 93.20249588365934, mean_custom_reward = 184.10253831583282, m_merged_reward = 93.20249588365934
# 0.1
#
# episode: 221, mean_total_reward = 93.05702706659997, mean_custom_reward = 183.98080709701077, m_merged_reward = 93.05702706659997
# 0.1
#
# episode: 222, mean_total_reward = 95.64518107514752, mean_custom_reward = 187.7946163912023, m_merged_reward = 95.64518107514752
# 0.1
#
# episode: 223, mean_total_reward = 95.78022320079981, mean_custom_reward = 187.23336339119768, m_merged_reward = 95.78022320079981
# 0.1
#
# episode: 224, mean_total_reward = 94.5577054624658, mean_custom_reward = 185.86036322577576, m_merged_reward = 94.5577054624658
# 0.1
#
# episode: 225, mean_total_reward = 95.76554022173659, mean_custom_reward = 187.20546094627684, m_merged_reward = 95.76554022173659
# 0.1
#
# episode: 226, mean_total_reward = 95.87554920954072, mean_custom_reward = 187.0963635691593, m_merged_reward = 95.87554920954072
# 0.1
#
# episode: 227, mean_total_reward = 93.32786185650771, mean_custom_reward = 183.0805341998445, m_merged_reward = 93.32786185650771
# 0.1
#
# episode: 228, mean_total_reward = 94.71249611790752, mean_custom_reward = 185.55928506653999, m_merged_reward = 94.71249611790752
# 0.1
#
# episode: 229, mean_total_reward = 94.5166927618014, mean_custom_reward = 185.68602719399962, m_merged_reward = 94.5166927618014
# 0.1
#
# episode: 230, mean_total_reward = 94.48491978696339, mean_custom_reward = 186.07803026237974, m_merged_reward = 94.48491978696339
# 0.1
#
# episode: 231, mean_total_reward = 94.83557675193809, mean_custom_reward = 185.22903274854278, m_merged_reward = 94.83557675193809
# 0.1
#
# episode: 232, mean_total_reward = 94.72500787572828, mean_custom_reward = 185.00976827406978, m_merged_reward = 94.72500787572828
# 0.1
#
# episode: 233, mean_total_reward = 94.58416714942362, mean_custom_reward = 185.0297652807504, m_merged_reward = 94.58416714942362
# 0.1
#
# episode: 234, mean_total_reward = 95.79450135786693, mean_custom_reward = 187.18056447303184, m_merged_reward = 95.79450135786693
# 0.1
#
# episode: 235, mean_total_reward = 96.02377092443665, mean_custom_reward = 187.14558864697813, m_merged_reward = 96.02377092443665
# 0.1
#
# episode: 236, mean_total_reward = 92.28997104965791, mean_custom_reward = 182.6260426839803, m_merged_reward = 92.28997104965791
# 0.1
#
# episode: 237, mean_total_reward = 92.48119689690051, mean_custom_reward = 182.6999513622235, m_merged_reward = 92.48119689690051
# 0.1
#
# episode: 238, mean_total_reward = 89.96953986361578, mean_custom_reward = 178.16107384233334, m_merged_reward = 89.96953986361578
# 0.1
#
# episode: 239, mean_total_reward = 93.5021324421794, mean_custom_reward = 183.9784572370582, m_merged_reward = 93.5021324421794
# 0.1
#
# episode: 240, mean_total_reward = 92.62924891312184, mean_custom_reward = 181.4172707177507, m_merged_reward = 92.62924891312184
# 0.1
#
# episode: 241, mean_total_reward = 96.23228295868323, mean_custom_reward = 187.13252123790568, m_merged_reward = 96.23228295868323
# 0.1
#
# episode: 242, mean_total_reward = 93.95006385370182, mean_custom_reward = 184.0682511570131, m_merged_reward = 93.95006385370182
# 0.1
#
# episode: 243, mean_total_reward = 93.5443396118492, mean_custom_reward = 183.40912675272077, m_merged_reward = 93.5443396118492
# 0.1
#
# episode: 244, mean_total_reward = 92.5078791767291, mean_custom_reward = 181.88831438032977, m_merged_reward = 92.5078791767291
# 0.1
#
# episode: 245, mean_total_reward = 93.63288767607058, mean_custom_reward = 184.0441164596456, m_merged_reward = 93.63288767607058
# 0.1
#
# episode: 246, mean_total_reward = 88.7870057793014, mean_custom_reward = 175.76629898540594, m_merged_reward = 88.7870057793014
# 0.1
#
# episode: 247, mean_total_reward = 91.25492230508829, mean_custom_reward = 180.4901897165248, m_merged_reward = 91.25492230508829
# 0.1
#
# episode: 248, mean_total_reward = 92.7179568290915, mean_custom_reward = 181.68367303229815, m_merged_reward = 92.7179568290915
# 0.1
#
# episode: 249, mean_total_reward = 93.76133638582569, mean_custom_reward = 184.54053554375855, m_merged_reward = 93.76133638582569
# 0.1
#
# episode: 250, mean_total_reward = 95.20367640626247, mean_custom_reward = 185.40225247505973, m_merged_reward = 95.20367640626247
# 0.1
#
# episode: 251, mean_total_reward = 96.25339361059568, mean_custom_reward = 187.2084512110377, m_merged_reward = 96.25339361059568
# 0.1
#
# episode: 252, mean_total_reward = 90.25126788248893, mean_custom_reward = 177.0298518188673, m_merged_reward = 90.25126788248893
# 0.1
#
# episode: 253, mean_total_reward = 93.62254144573149, mean_custom_reward = 182.56596582337474, m_merged_reward = 93.62254144573149
# 0.1
#
# episode: 254, mean_total_reward = 91.53808548886936, mean_custom_reward = 180.2118012198313, m_merged_reward = 91.53808548886936
# 0.1
#
# episode: 255, mean_total_reward = 85.01654698601034, mean_custom_reward = 171.58279048712436, m_merged_reward = 85.01654698601034
# 0.1
#
# episode: 256, mean_total_reward = 90.08836628139105, mean_custom_reward = 179.01574035336898, m_merged_reward = 90.08836628139105
# 0.1
#
# episode: 257, mean_total_reward = 90.01330295187813, mean_custom_reward = 178.52156257163693, m_merged_reward = 90.01330295187813
# 0.1
#
# episode: 258, mean_total_reward = 90.25721918744173, mean_custom_reward = 177.6715676114395, m_merged_reward = 90.25721918744173
# 0.1
#
# episode: 259, mean_total_reward = 88.86990150301654, mean_custom_reward = 175.9598891953944, m_merged_reward = 88.86990150301654
# 0.1
#
# episode: 260, mean_total_reward = 86.49108883756301, mean_custom_reward = 170.85700472191482, m_merged_reward = 86.49108883756301
# 0.1
#
# episode: 261, mean_total_reward = 92.79008107924928, mean_custom_reward = 181.62753145854558, m_merged_reward = 92.79008107924928
# 0.1
#
# episode: 262, mean_total_reward = 86.24401030281066, mean_custom_reward = 172.2116650929599, m_merged_reward = 86.24401030281066
# 0.1
#
# episode: 263, mean_total_reward = 88.85010907049863, mean_custom_reward = 176.63832371000316, m_merged_reward = 88.85010907049863
# 0.1
#
# episode: 264, mean_total_reward = 91.06818293999014, mean_custom_reward = 179.9201161323876, m_merged_reward = 91.06818293999014
# 0.1
#
# episode: 265, mean_total_reward = 93.71755467107577, mean_custom_reward = 183.46296945449006, m_merged_reward = 93.71755467107577
# 0.1
#
# episode: 266, mean_total_reward = 84.72120666073614, mean_custom_reward = 172.66334821872996, m_merged_reward = 84.72120666073614
# 0.1
#
# episode: 267, mean_total_reward = 90.0182476647265, mean_custom_reward = 179.18639390047016, m_merged_reward = 90.0182476647265
# 0.1
#
# episode: 268, mean_total_reward = 88.64142372646556, mean_custom_reward = 177.5706678189772, m_merged_reward = 88.64142372646556
# 0.1
#
# episode: 269, mean_total_reward = 88.85713995903397, mean_custom_reward = 177.38140424431987, m_merged_reward = 88.85713995903397
# 0.1
#
# episode: 270, mean_total_reward = 91.0468647345437, mean_custom_reward = 180.03032672022312, m_merged_reward = 91.0468647345437
# 0.1
#
# episode: 271, mean_total_reward = 90.10269100387139, mean_custom_reward = 176.97756023388314, m_merged_reward = 90.10269100387139
# 0.1
#
# episode: 272, mean_total_reward = 90.9022572596073, mean_custom_reward = 180.40822594889886, m_merged_reward = 90.9022572596073
# 0.1
#
# episode: 273, mean_total_reward = 82.75181611371286, mean_custom_reward = 166.63635965029908, m_merged_reward = 82.75181611371286
# 0.1
#
# episode: 274, mean_total_reward = 89.91037531835268, mean_custom_reward = 177.67032300857986, m_merged_reward = 89.91037531835268
# 0.1
#
# episode: 275, mean_total_reward = 93.57867667436187, mean_custom_reward = 183.8329167788135, m_merged_reward = 93.57867667436187
# 0.1
#
# episode: 276, mean_total_reward = 92.37350866426429, mean_custom_reward = 181.81943792495258, m_merged_reward = 92.37350866426429
# 0.1
#
# episode: 277, mean_total_reward = 90.97237840633179, mean_custom_reward = 180.41688107398727, m_merged_reward = 90.97237840633179
# 0.1
#
# episode: 278, mean_total_reward = 91.1241332640636, mean_custom_reward = 180.1324346914078, m_merged_reward = 91.1241332640636
# 0.1
#
# episode: 279, mean_total_reward = 88.49666714250122, mean_custom_reward = 176.5923213802997, m_merged_reward = 88.49666714250122
# 0.1
#
# episode: 280, mean_total_reward = 86.298808643123, mean_custom_reward = 172.67950200710007, m_merged_reward = 86.298808643123
# 0.1
#
# episode: 281, mean_total_reward = 90.10402676803498, mean_custom_reward = 177.88813618807504, m_merged_reward = 90.10402676803498
# 0.1
#
# episode: 282, mean_total_reward = 92.4125604592015, mean_custom_reward = 181.42140570794862, m_merged_reward = 92.4125604592015
# 0.1
#
# episode: 283, mean_total_reward = 87.59612448736974, mean_custom_reward = 173.9114627935773, m_merged_reward = 87.59612448736974
# 0.1
#
# episode: 284, mean_total_reward = 90.37678145450556, mean_custom_reward = 177.64069989534696, m_merged_reward = 90.37678145450556
# 0.1
#
# episode: 285, mean_total_reward = 87.63804093256076, mean_custom_reward = 174.8435006246543, m_merged_reward = 87.63804093256076
# 0.1
#
# episode: 286, mean_total_reward = 92.62796085292817, mean_custom_reward = 182.3404959627738, m_merged_reward = 92.62796085292817
# 0.1
#
# episode: 287, mean_total_reward = 85.22653255948923, mean_custom_reward = 170.53583183500606, m_merged_reward = 85.22653255948923
# 0.1
#
# episode: 288, mean_total_reward = 81.60270471082002, mean_custom_reward = 165.52906002878223, m_merged_reward = 81.60270471082002
# 0.1
#
# episode: 289, mean_total_reward = 86.71353018536941, mean_custom_reward = 173.6172207895998, m_merged_reward = 86.71353018536941
# 0.1
#
# episode: 290, mean_total_reward = 87.85504733884679, mean_custom_reward = 174.1016828727113, m_merged_reward = 87.85504733884679
# 0.1
#
# episode: 291, mean_total_reward = 90.30189855793863, mean_custom_reward = 178.4080593955815, m_merged_reward = 90.30189855793863
# 0.1
#
# episode: 292, mean_total_reward = 92.72918673196975, mean_custom_reward = 180.81369467979098, m_merged_reward = 92.72918673196975
# 0.1
#
# episode: 293, mean_total_reward = 89.22846500463154, mean_custom_reward = 176.2817661325937, m_merged_reward = 89.22846500463154
# 0.1
#
# episode: 294, mean_total_reward = 85.20569314957035, mean_custom_reward = 170.36412739219696, m_merged_reward = 85.20569314957035
# 0.1
#
# episode: 295, mean_total_reward = 86.71326322191736, mean_custom_reward = 173.36712345555708, m_merged_reward = 86.71326322191736
# 0.1
#
# episode: 296, mean_total_reward = 88.95579779774846, mean_custom_reward = 176.74373625825672, m_merged_reward = 88.95579779774846
# 0.1
#
# episode: 297, mean_total_reward = 89.11809011707811, mean_custom_reward = 175.2033188208865, m_merged_reward = 89.11809011707811
# 0.1
#
# episode: 298, mean_total_reward = 89.09147492674947, mean_custom_reward = 175.87615026754537, m_merged_reward = 89.09147492674947
# 0.1
#
# episode: 299, mean_total_reward = 89.17836733791198, mean_custom_reward = 177.6006520804729, m_merged_reward = 89.17836733791198
# 0.1

# %%
get_trajectory(env, agent, 1000,visualize=True, exploration=0)
print()
# Out:
# 150 96.9682131673148

# %%
torch.save(agent.state_dict(), 'MountainCarContinuous10_best.model')

# %%
agent = CEM(state_dim, action_dim)
agent.load_state_dict(torch.load('MountainCarContinuous10_205.model'))
#model.eval()
# Out:
# <All keys matched successfully>

# %%
fig = plt.figure(figsize=[14,10])
plt.plot(np.array(learnin_hist['validation'])[:,0],np.array(learnin_hist['validation'])[:,1],label='train',c='b')
plt.ylabel('validation',c='blue')
plt.xlabel('episode number')
plt.grid(True)
plt.twinx()
plt.plot(np.array(learnin_hist['exploration'])[:,0],np.array(learnin_hist['exploration'])[:,1],label='exploration',c='r')
plt.grid(True)
plt.xlabel('episode number')
plt.ylabel('exploration factor',c='red')
plt.savefig('train.png',dpi=300,bbox_inches='tight',facecolor='white')
