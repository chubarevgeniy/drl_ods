# %%
import torch
from torch import nn 
import numpy as np
import gym
import matplotlib.pyplot as plt
import json
# Out:
# Warning: Gym version v0.24.0 has a number of critical issues with `gym.make` such that the `reset` and `step` functions are called before returning the environment. It is recommend to downgrading to v0.23.1 or upgrading to v0.25.1

# %%
class CEM(nn.Module):
    def __init__(self, state_dim, action_dim):
        super().__init__()
        self.device = torch.device('cuda')
        self.state_dim = state_dim
        self.action_dim = action_dim
        
        self.network = nn.Sequential(
            nn.Linear(self.state_dim, 64), 
            nn.LeakyReLU(), 
            nn.Linear(64, self.action_dim)
        )
        #self.network.to(self.device)
        
        self.tanh = nn.Tanh()
        self.optimizer = torch.optim.Adam(self.parameters(), lr=0.01)
        self.loss = nn.L1Loss()
        
    def forward(self, _input):
        #_input = _input.to(self.device)
        return self.network(_input)
    
    def get_action(self, state, exploration=0):
        state = torch.FloatTensor(state)
        #logits = self.forward(state).to('cpu')
        pure_action = self.forward(state).detach().numpy()
        #pure_action += exploration*np.random.randn(self.action_dim)
        action = pure_action + exploration*np.random.randn(self.action_dim)
        return np.clip(action,-1,1)
    
    def update_policy(self, elite_trajectories):
        elite_states = []
        elite_actions = []
        for trajectory in elite_trajectories:
            elite_states.extend(trajectory['states'])
            elite_actions.extend(trajectory['actions'])
        elite_states = torch.FloatTensor(np.array(elite_states))
        #elite_states = elite_states.to(self.device)
        elite_actions = torch.FloatTensor(np.array(elite_actions))
        #elite_actions = elite_actions.to(self.device)
        for i in range(15):
            self.optimizer.zero_grad()
            loss = self.loss(self.forward(elite_states), elite_actions)
            loss.backward()
            self.optimizer.step()

# %%
def get_trajectory(env, agent, trajectory_len, exploration=0, visualize=False, custom_reward_func = None):
    trajectory = {'states':[], 'actions': [], 'total_reward': 0, 'custom_reward': 0}
    
    state = env.reset()
    trajectory['states'].append(state)
    for i in range(trajectory_len):
        with torch.no_grad():
            action = agent.get_action(state, exploration)
        trajectory['actions'].append(action)
        
        state, reward, done, _ = env.step(action)
        trajectory['total_reward'] += reward
        if custom_reward_func:
            reward = custom_reward_func(state) + reward
            trajectory['custom_reward'] = np.max([trajectory['custom_reward'],reward])
        
        if done:
            break
            
        if visualize:
            env.render()
        
        if(i != trajectory_len-1):
            trajectory['states'].append(state)
    
    if visualize:
        print(i,trajectory['total_reward'])  
    return trajectory

# %%
def get_elite_trajectories(trajectories, q_param, solved_traj):
    total_rewards = [trajectory['total_reward'] for trajectory in trajectories]
    quantile = np.quantile(total_rewards, q=q_param)
    new_solved = [trajectory for trajectory in trajectories if trajectory['total_reward'] >= 200]
    if(len(new_solved)):
        solved_traj.extend(new_solved)
        pass
    return [trajectory for trajectory in trajectories if trajectory['total_reward'] >= quantile]

# %%
env = gym.make("LunarLander-v2", continuous = True)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
learnin_hist = {'mean_reward': [], 'exploration': [], 'validation': []}

agent = CEM(state_dim, action_dim)

# %%
trajectory_len = 400
q_param = 0.8
exploration = 0.9
e_rate = 0.993
solved_traj = []

# %%
# %%time
episode_n = 1000
trajectory_n = 20

for episode in range(0,episode_n):
    trajectories = [get_trajectory(env, agent, trajectory_len, exploration) for _ in range(trajectory_n)]
    exploration *= e_rate
    mean_total_reward = np.mean([trajectory['total_reward'] for trajectory in trajectories])
    print(f'episode: {episode}, mean_total_reward = {mean_total_reward}')
    elite_trajectories = get_elite_trajectories(trajectories, q_param, solved_traj)
    print('solved =',len(solved_traj),' elite len =',len(elite_trajectories))
    learnin_hist['exploration'].append([episode,mean_total_reward])
    learnin_hist['mean_reward'].append([episode,mean_total_reward])
    if episode%10==0:
        trajectories = [get_trajectory(env, agent, trajectory_len, -1) for _ in range(trajectory_n*3)]
        mean_total_reward = np.mean([trajectory['total_reward'] for trajectory in trajectories])
        if(mean_total_reward>2600):
            break
        learnin_hist['validation'].append([episode,mean_total_reward])
        print('validation =', mean_total_reward)
    if len(elite_trajectories) > 0:
        if(len(solved_traj)>0):
            elite_trajectories.append(solved_traj[np.random.randint(len(solved_traj))])
            agent.update_policy(elite_trajectories)
        else:
            agent.update_policy(elite_trajectories)
# Out:
# episode: 0, mean_total_reward = -319.76999299915684
# solved = 0  elite len = 4
# validation = -295.1006663372406
# episode: 1, mean_total_reward = -157.3460979088721
# solved = 0  elite len = 4
# episode: 2, mean_total_reward = -103.33966357107833
# solved = 0  elite len = 4
# episode: 3, mean_total_reward = -97.47856866109315
# solved = 0  elite len = 4
# episode: 4, mean_total_reward = -131.05336434714332
# solved = 0  elite len = 4
# episode: 5, mean_total_reward = -93.40780874917138
# solved = 0  elite len = 4
# episode: 6, mean_total_reward = -85.07099151126096
# solved = 0  elite len = 4
# episode: 7, mean_total_reward = -40.52048654238282
# solved = 0  elite len = 4
# episode: 8, mean_total_reward = -11.906265147680536
# solved = 0  elite len = 4
# episode: 9, mean_total_reward = -18.57651619345267
# solved = 0  elite len = 4
# episode: 10, mean_total_reward = 3.6704759902798942
# solved = 0  elite len = 4
# validation = -6.61739758814976
# episode: 11, mean_total_reward = 9.566338142360586
# solved = 0  elite len = 4
# episode: 12, mean_total_reward = 35.22423982604905
# solved = 0  elite len = 4
# episode: 13, mean_total_reward = 9.943062958850993
# solved = 0  elite len = 4
# episode: 14, mean_total_reward = -37.219565404400484
# solved = 0  elite len = 4
# episode: 15, mean_total_reward = -51.76414420816583
# solved = 0  elite len = 4
# episode: 16, mean_total_reward = -13.823917365201282
# solved = 0  elite len = 4
# episode: 17, mean_total_reward = 2.2695446827894585
# solved = 0  elite len = 4
# episode: 18, mean_total_reward = -48.967395809349945
# solved = 0  elite len = 4
# episode: 19, mean_total_reward = -8.393447216160308
# solved = 0  elite len = 4
# episode: 20, mean_total_reward = -0.9471706701078461
# solved = 0  elite len = 4
# validation = -35.410366496715135
# episode: 21, mean_total_reward = -30.979630911777868
# solved = 0  elite len = 4
# episode: 22, mean_total_reward = 23.631364161955947
# solved = 0  elite len = 4
# episode: 23, mean_total_reward = 25.802220377451967
# solved = 0  elite len = 4
# episode: 24, mean_total_reward = -10.03405911044882
# solved = 0  elite len = 4
# episode: 25, mean_total_reward = 31.189817919192556
# solved = 0  elite len = 4
# episode: 26, mean_total_reward = 41.69734222303356
# solved = 0  elite len = 4
# episode: 27, mean_total_reward = 32.526004149161665
# solved = 0  elite len = 4
# episode: 28, mean_total_reward = 7.097300088625161
# solved = 0  elite len = 4
# episode: 29, mean_total_reward = 50.77103330058077
# solved = 0  elite len = 4
# episode: 30, mean_total_reward = 73.23421513720153
# solved = 0  elite len = 4
# validation = 37.137563848628
# episode: 31, mean_total_reward = 64.06149969795808
# solved = 0  elite len = 4
# episode: 32, mean_total_reward = 92.5195998098225
# solved = 0  elite len = 4
# episode: 33, mean_total_reward = 124.15296815192634
# solved = 0  elite len = 4
# episode: 34, mean_total_reward = 63.800432894235996
# solved = 0  elite len = 4
# episode: 35, mean_total_reward = 129.1206647016742
# solved = 0  elite len = 4
# episode: 36, mean_total_reward = 123.95176545395475
# solved = 0  elite len = 4
# episode: 37, mean_total_reward = 115.85452288171969
# solved = 0  elite len = 4
# episode: 38, mean_total_reward = 87.63201297900142
# solved = 1  elite len = 4
# episode: 39, mean_total_reward = 84.41326879099623
# solved = 1  elite len = 4
# episode: 40, mean_total_reward = 61.81787781869648
# solved = 1  elite len = 4
# validation = 45.50241435306234
# episode: 41, mean_total_reward = 96.52429122549977
# solved = 1  elite len = 4
# episode: 42, mean_total_reward = 97.55106697754167
# solved = 1  elite len = 4
# episode: 43, mean_total_reward = 96.17073369241726
# solved = 1  elite len = 4
# episode: 44, mean_total_reward = 92.6175160698642
# solved = 1  elite len = 4
# episode: 45, mean_total_reward = 115.14414770418298
# solved = 1  elite len = 4
# episode: 46, mean_total_reward = 91.63109258682566
# solved = 1  elite len = 4
# episode: 47, mean_total_reward = 80.69271879920413
# solved = 1  elite len = 4
# episode: 48, mean_total_reward = 115.34385899980796
# solved = 2  elite len = 4
# episode: 49, mean_total_reward = 95.63796204578288
# solved = 2  elite len = 4
# episode: 50, mean_total_reward = 80.2674884681766
# solved = 2  elite len = 4
# validation = 41.39356685953505
# episode: 51, mean_total_reward = 109.73224653160193
# solved = 2  elite len = 4
# episode: 52, mean_total_reward = 92.24485206217399
# solved = 3  elite len = 4
# episode: 53, mean_total_reward = 102.07220573767779
# solved = 3  elite len = 4
# episode: 54, mean_total_reward = 126.404936858413
# solved = 4  elite len = 4
# episode: 55, mean_total_reward = 86.61745748304614
# solved = 4  elite len = 4
# episode: 56, mean_total_reward = 84.93922037727562
# solved = 4  elite len = 4
# episode: 57, mean_total_reward = 113.94898947797085
# solved = 4  elite len = 4
# episode: 58, mean_total_reward = 124.23003795189788
# solved = 4  elite len = 4
# episode: 59, mean_total_reward = 100.28476559604982
# solved = 4  elite len = 4
# episode: 60, mean_total_reward = 84.55081411099259
# solved = 4  elite len = 4
# validation = 68.06919900692927
# episode: 61, mean_total_reward = 87.66972153612052
# solved = 4  elite len = 4
# episode: 62, mean_total_reward = 105.202134365781
# solved = 4  elite len = 4
# episode: 63, mean_total_reward = 103.71689556700339
# solved = 5  elite len = 4
# episode: 64, mean_total_reward = 134.8286236745175
# solved = 5  elite len = 4
# episode: 65, mean_total_reward = 82.09622751866218
# solved = 5  elite len = 4
# episode: 66, mean_total_reward = 82.68118564776087
# solved = 5  elite len = 4
# episode: 67, mean_total_reward = 41.58684655702226
# solved = 5  elite len = 4
# episode: 68, mean_total_reward = 103.79623147197735
# solved = 5  elite len = 4
# episode: 69, mean_total_reward = 88.68260314684537
# solved = 5  elite len = 4
# episode: 70, mean_total_reward = 59.8761821991684
# solved = 5  elite len = 4
# validation = 23.33898463171349
# episode: 71, mean_total_reward = 39.7049436081865
# solved = 6  elite len = 4
# episode: 72, mean_total_reward = 24.320307647623405
# solved = 6  elite len = 4
# episode: 73, mean_total_reward = 28.86980750619126
# solved = 6  elite len = 4
# episode: 74, mean_total_reward = 73.67792556860208
# solved = 7  elite len = 4
# episode: 75, mean_total_reward = 22.92466880635532
# solved = 7  elite len = 4
# episode: 76, mean_total_reward = 19.215233890969373
# solved = 7  elite len = 4
# episode: 77, mean_total_reward = 96.30482903778389
# solved = 7  elite len = 4
# episode: 78, mean_total_reward = 85.37563340943322
# solved = 7  elite len = 4
# episode: 79, mean_total_reward = 22.9168428477825
# solved = 7  elite len = 4
# episode: 80, mean_total_reward = 83.13548087519641
# solved = 7  elite len = 4
# validation = 29.88868215764517
# episode: 81, mean_total_reward = 58.43347909486816
# solved = 7  elite len = 4
# episode: 82, mean_total_reward = 77.226143057931
# solved = 7  elite len = 4
# episode: 83, mean_total_reward = -29.520707435756595
# solved = 7  elite len = 4
# episode: 84, mean_total_reward = -34.49147137053788
# solved = 7  elite len = 4
# episode: 85, mean_total_reward = -34.19132084942525
# solved = 7  elite len = 4
# episode: 86, mean_total_reward = 24.64982826665132
# solved = 7  elite len = 4
# episode: 87, mean_total_reward = 63.654646075004585
# solved = 7  elite len = 4
# episode: 88, mean_total_reward = 59.33294975963256
# solved = 7  elite len = 4
# episode: 89, mean_total_reward = 26.26658156848898
# solved = 7  elite len = 4
# episode: 90, mean_total_reward = 47.02384298400502
# solved = 7  elite len = 4
# validation = -53.28212290159675
# episode: 91, mean_total_reward = 84.054426441716
# solved = 7  elite len = 4
# episode: 92, mean_total_reward = 109.7704175654773
# solved = 8  elite len = 4
# episode: 93, mean_total_reward = 28.459217060406264
# solved = 8  elite len = 4
# episode: 94, mean_total_reward = 65.39965269965549
# solved = 8  elite len = 4
# episode: 95, mean_total_reward = 108.5937345857895
# solved = 9  elite len = 4
# episode: 96, mean_total_reward = 121.21414300845345
# solved = 10  elite len = 4
# episode: 97, mean_total_reward = 6.841801475638211
# solved = 10  elite len = 4
# episode: 98, mean_total_reward = 109.33072358308091
# solved = 10  elite len = 4
# episode: 99, mean_total_reward = 110.85446117279233
# solved = 11  elite len = 4
# episode: 100, mean_total_reward = 98.90982577482939
# solved = 12  elite len = 4
# validation = 16.094540702966047
# episode: 101, mean_total_reward = 132.79780562792496
# solved = 12  elite len = 4
# episode: 102, mean_total_reward = 108.21819513171906
# solved = 12  elite len = 4
# episode: 103, mean_total_reward = 71.29789894480302
# solved = 14  elite len = 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:5, in <module>
#
# File <timed exec>:5, in <listcomp>(.0)
#
# Input In [3], in get_trajectory(env, agent, trajectory_len, exploration, visualize, custom_reward_func)
#       6 for i in range(trajectory_len):
#       7     with torch.no_grad():
# ----> 8         action = agent.get_action(state, exploration)
#       9     trajectory['actions'].append(action)
#      11     state, reward, done, _ = env.step(action)
#
# Input In [2], in CEM.get_action(self, state, exploration)
#      24 state = torch.FloatTensor(state)
#      25 #logits = self.forward(state).to('cpu')
# ---> 26 pure_action = self.forward(state).detach().numpy()
#      27 #pure_action += exploration*np.random.randn(self.action_dim)
#      28 action = pure_action + exploration*np.random.randn(self.action_dim)
#
# Input In [2], in CEM.forward(self, _input)
#      19 def forward(self, _input):
#      20     #_input = _input.to(self.device)
# ---> 21     return self.network(_input)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\container.py:139, in Sequential.forward(self, input)
#     137 def forward(self, input):
#     138     for module in self:
# --> 139         input = module(input)
#     140     return input
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\activation.py:772, in LeakyReLU.forward(self, input)
#     771 def forward(self, input: Tensor) -> Tensor:
# --> 772     return F.leaky_relu(input, self.negative_slope, self.inplace)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\functional.py:1633, in leaky_relu(input, negative_slope, inplace)
#    1631     result = torch._C._nn.leaky_relu_(input, negative_slope)
#    1632 else:
# -> 1633     result = torch._C._nn.leaky_relu(input, negative_slope)
#    1634 return result
#
# KeyboardInterrupt:

# %%
hist = np.array(learnin_hist['mean_reward'])
hist = hist[:400,:]

# %%
hist[:,0] *= trajectory_n

# %%
plt.plot(hist[:,0],hist[:,1])

# %%
np.savetxt('ce4.txt',hist)
