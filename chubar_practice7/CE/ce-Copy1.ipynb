# %%
import torch
from torch import nn 
import numpy as np
import gym
import matplotlib.pyplot as plt
import json
# Out:
# Warning: Gym version v0.24.0 has a number of critical issues with `gym.make` such that the `reset` and `step` functions are called before returning the environment. It is recommend to downgrading to v0.23.1 or upgrading to v0.25.1

# %%
class CEM(nn.Module):
    def __init__(self, state_dim, action_dim):
        super().__init__()
        self.device = torch.device('cuda')
        self.state_dim = state_dim
        self.action_dim = action_dim
        
        self.network = nn.Sequential(
            nn.Linear(self.state_dim, 64), 
            nn.LeakyReLU(), 
            nn.Linear(64, self.action_dim)
        )
        #self.network.to(self.device)
        
        self.tanh = nn.Tanh()
        self.optimizer = torch.optim.Adam(self.parameters(), lr=0.01)
        self.loss = nn.L1Loss()
        
    def forward(self, _input):
        #_input = _input.to(self.device)
        return self.network(_input)
    
    def get_action(self, state, exploration=0):
        state = torch.FloatTensor(state)
        #logits = self.forward(state).to('cpu')
        pure_action = self.forward(state).detach().numpy()
        #pure_action += exploration*np.random.randn(self.action_dim)
        action = pure_action + exploration*np.random.randn(self.action_dim)
        return np.clip(action,-1,1)
    
    def update_policy(self, elite_trajectories):
        elite_states = []
        elite_actions = []
        for trajectory in elite_trajectories:
            elite_states.extend(trajectory['states'])
            elite_actions.extend(trajectory['actions'])
        elite_states = torch.FloatTensor(np.array(elite_states))
        #elite_states = elite_states.to(self.device)
        elite_actions = torch.FloatTensor(np.array(elite_actions))
        #elite_actions = elite_actions.to(self.device)
        for i in range(15):
            self.optimizer.zero_grad()
            loss = self.loss(self.forward(elite_states), elite_actions)
            loss.backward()
            self.optimizer.step()

# %%
def get_trajectory(env, agent, trajectory_len, exploration=0, visualize=False, custom_reward_func = None):
    trajectory = {'states':[], 'actions': [], 'total_reward': 0, 'custom_reward': 0}
    
    state = env.reset()
    trajectory['states'].append(state)
    for i in range(trajectory_len):
        with torch.no_grad():
            action = agent.get_action(state, exploration)
        trajectory['actions'].append(action)
        
        state, reward, done, _ = env.step(action)
        trajectory['total_reward'] += reward
        if custom_reward_func:
            reward = custom_reward_func(state) + reward
            trajectory['custom_reward'] = np.max([trajectory['custom_reward'],reward])
        
        if done:
            break
            
        if visualize:
            env.render()
        
        if(i != trajectory_len-1):
            trajectory['states'].append(state)
    
    if visualize:
        print(i,trajectory['total_reward'])  
    return trajectory

# %%
def get_elite_trajectories(trajectories, q_param, solved_traj):
    total_rewards = [trajectory['total_reward'] for trajectory in trajectories]
    quantile = np.quantile(total_rewards, q=q_param)
    new_solved = [trajectory for trajectory in trajectories if trajectory['total_reward'] >= 200]
    if(len(new_solved)):
        solved_traj.extend(new_solved)
        pass
    return [trajectory for trajectory in trajectories if trajectory['total_reward'] >= quantile]

# %%
env = gym.make("LunarLander-v2", continuous = True)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
learnin_hist = {'mean_reward': [], 'exploration': [], 'validation': []}

agent = CEM(state_dim, action_dim)

# %%
trajectory_len = 400
q_param = 0.8
exploration = 0.9
e_rate = 0.993
solved_traj = []

# %%
# %%time
episode_n = 1000
trajectory_n = 20

for episode in range(0,episode_n):
    trajectories = [get_trajectory(env, agent, trajectory_len, exploration) for _ in range(trajectory_n)]
    exploration *= e_rate
    mean_total_reward = np.mean([trajectory['total_reward'] for trajectory in trajectories])
    print(f'episode: {episode}, mean_total_reward = {mean_total_reward}')
    elite_trajectories = get_elite_trajectories(trajectories, q_param, solved_traj)
    print('solved =',len(solved_traj),' elite len =',len(elite_trajectories))
    learnin_hist['exploration'].append([episode,mean_total_reward])
    learnin_hist['mean_reward'].append([episode,mean_total_reward])
    if episode%10==0:
        trajectories = [get_trajectory(env, agent, trajectory_len, -1) for _ in range(trajectory_n*3)]
        mean_total_reward = np.mean([trajectory['total_reward'] for trajectory in trajectories])
        if(mean_total_reward>2600):
            break
        learnin_hist['validation'].append([episode,mean_total_reward])
        print('validation =', mean_total_reward)
    if len(elite_trajectories) > 0:
        if(len(solved_traj)>0):
            elite_trajectories.append(solved_traj[np.random.randint(len(solved_traj))])
            agent.update_policy(elite_trajectories)
        else:
            agent.update_policy(elite_trajectories)
# Out:
# episode: 0, mean_total_reward = -307.4299150719024
# solved = 0  elite len = 4
# validation = -299.8893569068221
# episode: 1, mean_total_reward = -185.08551264602323
# solved = 0  elite len = 4
# episode: 2, mean_total_reward = -153.15001343712817
# solved = 0  elite len = 4
# episode: 3, mean_total_reward = -113.4888897508049
# solved = 0  elite len = 4
# episode: 4, mean_total_reward = -116.31590474544353
# solved = 0  elite len = 4
# episode: 5, mean_total_reward = -66.65327735832824
# solved = 0  elite len = 4
# episode: 6, mean_total_reward = -46.82665523236115
# solved = 0  elite len = 4
# episode: 7, mean_total_reward = -36.62605679631861
# solved = 0  elite len = 4
# episode: 8, mean_total_reward = -29.25988542296534
# solved = 0  elite len = 4
# episode: 9, mean_total_reward = 4.188183445613201
# solved = 0  elite len = 4
# episode: 10, mean_total_reward = -44.000705111382196
# solved = 0  elite len = 4
# validation = -6.561843806158105
# episode: 11, mean_total_reward = 4.639131327204941
# solved = 0  elite len = 4
# episode: 12, mean_total_reward = 2.438574657091659
# solved = 0  elite len = 4
# episode: 13, mean_total_reward = 11.483943457086566
# solved = 0  elite len = 4
# episode: 14, mean_total_reward = 11.817589557519224
# solved = 0  elite len = 4
# episode: 15, mean_total_reward = -2.924794590048574
# solved = 0  elite len = 4
# episode: 16, mean_total_reward = 15.856291347739932
# solved = 0  elite len = 4
# episode: 17, mean_total_reward = 17.366839694917758
# solved = 0  elite len = 4
# episode: 18, mean_total_reward = 19.264569871805083
# solved = 0  elite len = 4
# episode: 19, mean_total_reward = 50.113665815499516
# solved = 0  elite len = 4
# episode: 20, mean_total_reward = -19.647633772734316
# solved = 0  elite len = 4
# validation = -17.862375262525358
# episode: 21, mean_total_reward = 11.789782496492162
# solved = 0  elite len = 4
# episode: 22, mean_total_reward = -9.504714698851927
# solved = 0  elite len = 4
# episode: 23, mean_total_reward = 19.34338815128653
# solved = 0  elite len = 4
# episode: 24, mean_total_reward = 70.58410580615893
# solved = 0  elite len = 4
# episode: 25, mean_total_reward = 36.887282140718796
# solved = 0  elite len = 4
# episode: 26, mean_total_reward = 57.83889689790941
# solved = 0  elite len = 4
# episode: 27, mean_total_reward = 89.13625133881688
# solved = 1  elite len = 4
# episode: 28, mean_total_reward = 58.798875661440135
# solved = 1  elite len = 4
# episode: 29, mean_total_reward = 117.4709020374629
# solved = 2  elite len = 4
# episode: 30, mean_total_reward = 110.1032399413295
# solved = 2  elite len = 4
# validation = 69.60073054832073
# episode: 31, mean_total_reward = 57.51535093991164
# solved = 2  elite len = 4
# episode: 32, mean_total_reward = 52.05930122683069
# solved = 2  elite len = 4
# episode: 33, mean_total_reward = 72.99306463333821
# solved = 2  elite len = 4
# episode: 34, mean_total_reward = 102.25855911046993
# solved = 3  elite len = 4
# episode: 35, mean_total_reward = 65.02830158170849
# solved = 3  elite len = 4
# episode: 36, mean_total_reward = 106.92121313632147
# solved = 3  elite len = 4
# episode: 37, mean_total_reward = 80.36195465370017
# solved = 3  elite len = 4
# episode: 38, mean_total_reward = 87.2729123380589
# solved = 3  elite len = 4
# episode: 39, mean_total_reward = 62.80319227173036
# solved = 4  elite len = 4
# episode: 40, mean_total_reward = 39.261063646629154
# solved = 4  elite len = 4
# validation = -13.072668649983973
# episode: 41, mean_total_reward = 7.754972855912873
# solved = 4  elite len = 4
# episode: 42, mean_total_reward = 64.98300535470916
# solved = 4  elite len = 4
# episode: 43, mean_total_reward = 64.86075729031533
# solved = 4  elite len = 4
# episode: 44, mean_total_reward = 63.2650935530098
# solved = 4  elite len = 4
# episode: 45, mean_total_reward = 68.44095032924393
# solved = 5  elite len = 4
# episode: 46, mean_total_reward = 87.72911806503143
# solved = 5  elite len = 4
# episode: 47, mean_total_reward = 110.13735018286464
# solved = 6  elite len = 4
# episode: 48, mean_total_reward = 109.54565544793668
# solved = 6  elite len = 4
# episode: 49, mean_total_reward = 101.3690135850039
# solved = 8  elite len = 4
# episode: 50, mean_total_reward = 106.06646320962355
# solved = 9  elite len = 4
# validation = 35.615117301862796
# episode: 51, mean_total_reward = 138.5063775873861
# solved = 9  elite len = 4
# episode: 52, mean_total_reward = 100.20214577690702
# solved = 9  elite len = 4
# episode: 53, mean_total_reward = 114.37564752716553
# solved = 9  elite len = 4
# episode: 54, mean_total_reward = 136.5937313977539
# solved = 11  elite len = 4
# episode: 55, mean_total_reward = 139.30179527586924
# solved = 11  elite len = 4
# episode: 56, mean_total_reward = 67.901862309731
# solved = 12  elite len = 4
# episode: 57, mean_total_reward = 128.0774030329273
# solved = 12  elite len = 4
# episode: 58, mean_total_reward = 127.79968146211608
# solved = 13  elite len = 4
# episode: 59, mean_total_reward = 110.58028459192208
# solved = 13  elite len = 4
# episode: 60, mean_total_reward = 134.46111372521406
# solved = 16  elite len = 4
# validation = 46.48526587739301
# episode: 61, mean_total_reward = 111.40342772610047
# solved = 16  elite len = 4
# episode: 62, mean_total_reward = 99.96725413229073
# solved = 16  elite len = 4
# episode: 63, mean_total_reward = 85.72439041762175
# solved = 18  elite len = 4
# episode: 64, mean_total_reward = 97.35152446676031
# solved = 20  elite len = 4
# episode: 65, mean_total_reward = 95.66483375668014
# solved = 20  elite len = 4
# episode: 66, mean_total_reward = 134.90380499061948
# solved = 21  elite len = 4
# episode: 67, mean_total_reward = 132.62425652026712
# solved = 24  elite len = 4
# episode: 68, mean_total_reward = 110.31332233617437
# solved = 25  elite len = 4
# episode: 69, mean_total_reward = 122.07161270900356
# solved = 25  elite len = 4
# episode: 70, mean_total_reward = 71.92469005310227
# solved = 26  elite len = 4
# validation = 33.27853661627294
# episode: 71, mean_total_reward = 117.85042163948624
# solved = 28  elite len = 4
# episode: 72, mean_total_reward = 95.87491007312371
# solved = 29  elite len = 4
# episode: 73, mean_total_reward = 130.6652466283314
# solved = 32  elite len = 4
# episode: 74, mean_total_reward = 133.09400815377793
# solved = 34  elite len = 4
# episode: 75, mean_total_reward = 134.67585027256285
# solved = 35  elite len = 4
# episode: 76, mean_total_reward = 116.09063638541829
# solved = 37  elite len = 4
# episode: 77, mean_total_reward = 120.45749845131748
# solved = 39  elite len = 4
# episode: 78, mean_total_reward = 112.66111668543067
# solved = 40  elite len = 4
# episode: 79, mean_total_reward = 136.3488286462728
# solved = 41  elite len = 4
# episode: 80, mean_total_reward = 113.26521396040732
# solved = 42  elite len = 4
# validation = 3.7074401015774816
# episode: 81, mean_total_reward = 107.46410490450869
# solved = 42  elite len = 4
# episode: 82, mean_total_reward = 133.77690805930337
# solved = 43  elite len = 4
# episode: 83, mean_total_reward = 94.678538535376
# solved = 44  elite len = 4
# episode: 84, mean_total_reward = 109.68574582893523
# solved = 44  elite len = 4
# episode: 85, mean_total_reward = 141.91499154017362
# solved = 48  elite len = 4
# episode: 86, mean_total_reward = 90.10080164054249
# solved = 50  elite len = 4
# episode: 87, mean_total_reward = 4.37649223326553
# solved = 50  elite len = 4
# episode: 88, mean_total_reward = 24.49078546642155
# solved = 52  elite len = 4
# episode: 89, mean_total_reward = 65.90969281581074
# solved = 54  elite len = 4
# episode: 90, mean_total_reward = 44.01532939177651
# solved = 56  elite len = 4
# validation = -15.058323158854714
# episode: 91, mean_total_reward = 91.31148793436282
# solved = 57  elite len = 4
# episode: 92, mean_total_reward = 136.7614382154299
# solved = 58  elite len = 4
# episode: 93, mean_total_reward = 149.1594623132419
# solved = 58  elite len = 4
# episode: 94, mean_total_reward = 125.56570913339333
# solved = 59  elite len = 4
# episode: 95, mean_total_reward = 123.98309614039033
# solved = 61  elite len = 4
# episode: 96, mean_total_reward = 147.0732449441957
# solved = 62  elite len = 4
# episode: 97, mean_total_reward = 112.54711754673352
# solved = 63  elite len = 4
# episode: 98, mean_total_reward = 103.13855055779513
# solved = 63  elite len = 4
# episode: 99, mean_total_reward = 124.26800562036556
# solved = 67  elite len = 4
# episode: 100, mean_total_reward = 104.97265011372835
# solved = 68  elite len = 4
# validation = -8.86697950230619
# episode: 101, mean_total_reward = 74.88116952164262
# solved = 69  elite len = 4
# episode: 102, mean_total_reward = 136.9837455003416
# solved = 72  elite len = 4
# episode: 103, mean_total_reward = 93.70811237933056
# solved = 74  elite len = 4
# episode: 104, mean_total_reward = 119.7725053537616
# solved = 76  elite len = 4
# episode: 105, mean_total_reward = 178.71263228203753
# solved = 80  elite len = 4
# episode: 106, mean_total_reward = 135.6826239479527
# solved = 82  elite len = 4
# episode: 107, mean_total_reward = 111.21888709691757
# solved = 83  elite len = 4
# episode: 108, mean_total_reward = 100.16292136856491
# solved = 85  elite len = 4
# episode: 109, mean_total_reward = 157.64725601280708
# solved = 92  elite len = 4
# episode: 110, mean_total_reward = 144.32955405827354
# solved = 97  elite len = 4
# validation = -1.1610409350782507
# episode: 111, mean_total_reward = 122.34144454238353
# solved = 99  elite len = 4
# episode: 112, mean_total_reward = 158.74027580852456
# solved = 104  elite len = 4
# episode: 113, mean_total_reward = 134.8450714887266
# solved = 107  elite len = 4
# episode: 114, mean_total_reward = 150.36785249898165
# solved = 110  elite len = 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:5, in <module>
#
# File <timed exec>:5, in <listcomp>(.0)
#
# Input In [3], in get_trajectory(env, agent, trajectory_len, exploration, visualize, custom_reward_func)
#       6 for i in range(trajectory_len):
#       7     with torch.no_grad():
# ----> 8         action = agent.get_action(state, exploration)
#       9     trajectory['actions'].append(action)
#      11     state, reward, done, _ = env.step(action)
#
# Input In [2], in CEM.get_action(self, state, exploration)
#      24 state = torch.FloatTensor(state)
#      25 #logits = self.forward(state).to('cpu')
# ---> 26 pure_action = self.forward(state).detach().numpy()
#      27 #pure_action += exploration*np.random.randn(self.action_dim)
#      28 action = pure_action + exploration*np.random.randn(self.action_dim)
#
# Input In [2], in CEM.forward(self, _input)
#      19 def forward(self, _input):
#      20     #_input = _input.to(self.device)
# ---> 21     return self.network(_input)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\container.py:139, in Sequential.forward(self, input)
#     137 def forward(self, input):
#     138     for module in self:
# --> 139         input = module(input)
#     140     return input
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
hist = np.array(learnin_hist['mean_reward'])

hist = hist[:400,:]

# %%
hist[:,0] *= trajectory_n

# %%
plt.plot(hist[:,0],hist[:,1])

# %%
np.savetxt('ce1.txt',hist)
