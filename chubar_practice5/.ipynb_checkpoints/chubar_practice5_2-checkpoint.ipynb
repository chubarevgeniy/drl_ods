# %%
import numpy as np
import random
import torch
import torch.nn as nn
import gym
import matplotlib.pyplot as plt
from matplotlib import animation
import matplotlib.patches as patches

class Qfunction(nn.Module):
    def __init__(self, state_dim, action_dim):
        super().__init__()
        self.linear_1 = nn.Linear(state_dim, 64)
        self.linear_2 = nn.Linear(64, 64)
        self.linear_3 = nn.Linear(64, action_dim)
        self.activation = nn.LeakyReLU(0.1)

    def forward(self, states):
        hidden = self.linear_1(states)
        hidden = self.activation(hidden)
        hidden = self.linear_2(hidden)
        hidden = self.activation(hidden)
        actions = self.linear_3(hidden)
        return actions
# Out:
# Warning: Gym version v0.24.0 has a number of critical issues with `gym.make` such that the `reset` and `step` functions are called before returning the environment. It is recommend to downgrading to v0.23.1 or upgrading to v0.25.1

# %%
# %matplotlib inline

# %%
class HDQN:
    def __init__(self, state_dim, action_dim, gamma=0.993, lr=1e-3, batch_size=128, epsilon_decrease=0.01, epsilon_min=0.03):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.q_function = Qfunction(self.state_dim, self.action_dim)
        self.q_function_ = Qfunction(self.state_dim, self.action_dim)
        for target_param in self.q_function_.parameters():
            target_param.data.copy_(target_param.data*0)
        self.gamma = gamma
        self.batch_size = batch_size
        self.epsilon = 1
        self.epsilon_decrease = epsilon_decrease
        self.epsilon_min = epsilon_min
        self.memory = []
        self.memory_lim = 150000
        self.optimzaer = torch.optim.Adam(self.q_function.parameters(), lr=lr)

    def get_action(self, state, target= False):
        if(target):
            q_values = self.q_function_(torch.FloatTensor(state))
        else:
            q_values = self.q_function(torch.FloatTensor(state))
        argmax_action = torch.argmax(q_values,dim=-1)
        probs = self.epsilon * np.ones((argmax_action.shape[0],self.action_dim)) / self.action_dim
        probs[np.arange(argmax_action.shape[0]),argmax_action] += 1 - self.epsilon
        action = np.ones(q_values.shape[0], dtype=np.int32)
        for sample in range(q_values.shape[0]):
            action[sample] = np.random.choice(np.arange(self.action_dim), p=probs[sample,:])
        return action
    
    def fit(self, state, action, reward, done, next_state, update_net = True):
        if(update_net):
            print('hard update')
            self.q_function_.load_state_dict(self.q_function.state_dict())
        self.memory.append([state, action, reward, int(done), next_state])
        if(len(self.memory)>self.memory_lim):
            self.memory = self.memory[int(self.memory_lim*0.05):]
            self.memory = random.sample(self.memory, int(self.memory_lim*0.9))
            print('clear memory')
        if len(self.memory) > self.batch_size:
            batch = random.sample(self.memory, self.batch_size)
            states, actions, rewards, dones, next_states = map(torch.tensor, list(zip(*batch)))
    
            targets = rewards + self.gamma * (1 - dones) * torch.max(self.q_function_(next_states), dim=1).values
            q_values = self.q_function(states)[torch.arange(self.batch_size), actions]
            
            loss = torch.mean((q_values - targets.detach()) ** 2)
            loss.backward()
            self.optimzaer.step()
            self.optimzaer.zero_grad()
            
            if self.epsilon > self.epsilon_min:
                self.epsilon -= self.epsilon_decrease

# %%
env = gym.make('LunarLander-v2')

# %%
# %%time
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

episode_n = 2000
t_max = 1000
do_clear = True

agent_h = HDQN(state_dim, action_dim,epsilon_decrease=0.03/episode_n)
hist_h = []
hist_h_v = []
hist_h_v_disc = []
hist_h_v_ = []
hist_h_v_disc_ = []

for episode in range(episode_n):
    total_reward = 0

    state = env.reset()
    for t in range(t_max):
        action = agent_h.get_action([state])
        next_state, reward, done, _ = env.step(action[0])

        total_reward += reward
        agent_h.fit(state, int(action), reward, done, next_state,update_net=(t == 0 and episode%25==0))

        state = next_state

        if done:
            break
    
    hist_h.append(total_reward)
    
    #validate
    if(episode%10 == 0):
        eps = agent_h.epsilon
        agent_h.epsilon = 0
        total_reward = 0
        total_reward_disc = 0
        rew_mult = 1
        state = env.reset()
        for t in range(t_max):
            action = agent_h.get_action([state], True)
            next_state, reward, done, _ = env.step(action[0])

            total_reward += reward
            
            total_reward_disc += rew_mult*reward
            rew_mult *= agent_h.gamma

            state = next_state

            if done:
                break
        agent_h.epsilon = eps
        
        hist_h_v_.append(total_reward)
        hist_h_v_disc_.append(total_reward_disc)
        
    
    if(episode%10 == 0):
        eps = agent_h.epsilon
        agent_h.epsilon = 0
        total_reward = 0
        total_reward_disc = 0
        rew_mult = 1
        state = env.reset()
        for t in range(t_max):
            action = agent_h.get_action([state], False)
            next_state, reward, done, _ = env.step(action[0])

            total_reward += reward
            
            total_reward_disc += rew_mult*reward
            rew_mult *= agent_h.gamma

            state = next_state

            if done:
                break
        agent_h.epsilon = eps
        
        hist_h_v.append(total_reward)
        hist_h_v_disc.append(total_reward_disc)
        
    if(np.mean(hist_h_v[-10:])>220 and np.mean(hist_h_v_[-10:])>220):
        break
    if(np.mean(hist_h_v[-10:])>240 or np.mean(hist_h_v_[-10:])>240):
        break

    print(f'episode: {episode}, \
rew: {round(np.mean(hist_h[-100:]),2)}, \
v_: {round(np.mean(hist_h_v_[-10:]),2)}, \
v_disc_: {round(np.mean(hist_h_v_disc_[-10:]),2)}, \
v: {round(np.mean(hist_h_v[-10:]),2)}, \
v_disc: {round(np.mean(hist_h_v_disc[-10:]),2)}, \
epsilon: {round(agent_h.epsilon,2)}, \
mem: {len(agent_h.memory)}')
# Out:
# hard update
# episode: 0, rew: -101.84, v_: -472.54, v_disc_: -347.43, v: -703.87, v_disc: -452.18, epsilon: 1, mem: 67
# episode: 1, rew: -115.01, v_: -472.54, v_disc_: -347.43, v: -703.87, v_disc: -452.18, epsilon: 1.0, mem: 145
# episode: 2, rew: -111.52, v_: -472.54, v_disc_: -347.43, v: -703.87, v_disc: -452.18, epsilon: 1.0, mem: 244
# episode: 3, rew: -113.14, v_: -472.54, v_disc_: -347.43, v: -703.87, v_disc: -452.18, epsilon: 1.0, mem: 364
# episode: 4, rew: -124.18, v_: -472.54, v_disc_: -347.43, v: -703.87, v_disc: -452.18, epsilon: 1.0, mem: 436
# episode: 5, rew: -121.63, v_: -472.54, v_disc_: -347.43, v: -703.87, v_disc: -452.18, epsilon: 0.99, mem: 560
# episode: 6, rew: -115.96, v_: -472.54, v_disc_: -347.43, v: -703.87, v_disc: -452.18, epsilon: 0.99, mem: 624
# episode: 7, rew: -163.8, v_: -472.54, v_disc_: -347.43, v: -703.87, v_disc: -452.18, epsilon: 0.99, mem: 756
# episode: 8, rew: -155.78, v_: -472.54, v_disc_: -347.43, v: -703.87, v_disc: -452.18, epsilon: 0.99, mem: 816
# episode: 9, rew: -149.03, v_: -472.54, v_disc_: -347.43, v: -703.87, v_disc: -452.18, epsilon: 0.99, mem: 876
# episode: 10, rew: -143.46, v_: -437.68, v_disc_: -327.02, v: -563.62, v_disc: -325.56, epsilon: 0.99, mem: 937
# episode: 11, rew: -137.54, v_: -437.68, v_disc_: -327.02, v: -563.62, v_disc: -325.56, epsilon: 0.99, mem: 1013
# episode: 12, rew: -133.01, v_: -437.68, v_disc_: -327.02, v: -563.62, v_disc: -325.56, epsilon: 0.99, mem: 1083
# episode: 13, rew: -130.33, v_: -437.68, v_disc_: -327.02, v: -563.62, v_disc: -325.56, epsilon: 0.98, mem: 1165
# episode: 14, rew: -133.14, v_: -437.68, v_disc_: -327.02, v: -563.62, v_disc: -325.56, epsilon: 0.98, mem: 1224
# episode: 15, rew: -133.05, v_: -437.68, v_disc_: -327.02, v: -563.62, v_disc: -325.56, epsilon: 0.98, mem: 1322
# episode: 16, rew: -132.11, v_: -437.68, v_disc_: -327.02, v: -563.62, v_disc: -325.56, epsilon: 0.98, mem: 1409
# episode: 17, rew: -139.44, v_: -437.68, v_disc_: -327.02, v: -563.62, v_disc: -325.56, epsilon: 0.98, mem: 1501
# episode: 18, rew: -138.49, v_: -437.68, v_disc_: -327.02, v: -563.62, v_disc: -325.56, epsilon: 0.98, mem: 1602
# episode: 19, rew: -136.38, v_: -437.68, v_disc_: -327.02, v: -563.62, v_disc: -325.56, epsilon: 0.98, mem: 1668
# episode: 20, rew: -141.6, v_: -532.28, v_disc_: -376.39, v: -447.6, v_disc: -268.59, epsilon: 0.98, mem: 1733
# episode: 21, rew: -142.93, v_: -532.28, v_disc_: -376.39, v: -447.6, v_disc: -268.59, epsilon: 0.97, mem: 1837
# episode: 22, rew: -139.62, v_: -532.28, v_disc_: -376.39, v: -447.6, v_disc: -268.59, epsilon: 0.97, mem: 1936
# episode: 23, rew: -139.64, v_: -532.28, v_disc_: -376.39, v: -447.6, v_disc: -268.59, epsilon: 0.97, mem: 2018
# episode: 24, rew: -137.42, v_: -532.28, v_disc_: -376.39, v: -447.6, v_disc: -268.59, epsilon: 0.97, mem: 2098
# hard update
# episode: 25, rew: -139.9, v_: -532.28, v_disc_: -376.39, v: -447.6, v_disc: -268.59, epsilon: 0.97, mem: 2183
# episode: 26, rew: -139.94, v_: -532.28, v_disc_: -376.39, v: -447.6, v_disc: -268.59, epsilon: 0.97, mem: 2299
# episode: 27, rew: -139.78, v_: -532.28, v_disc_: -376.39, v: -447.6, v_disc: -268.59, epsilon: 0.97, mem: 2412
# episode: 28, rew: -139.39, v_: -532.28, v_disc_: -376.39, v: -447.6, v_disc: -268.59, epsilon: 0.96, mem: 2488
# episode: 29, rew: -137.9, v_: -532.28, v_disc_: -376.39, v: -447.6, v_disc: -268.59, epsilon: 0.96, mem: 2594
# episode: 30, rew: -137.33, v_: -528.28, v_disc_: -355.93, v: -372.47, v_disc: -220.57, epsilon: 0
v_: -101.2, v_disc_: -13.16, v: 5.92, v_disc: 37.52, epsilon: 0.03, mem: 145645
# episode: 1308, rew: -16.13, v_: -101.2, v_disc_: -13.16, v: 5.92, v_disc: 37.52, epsilon: 0.03, mem: 146645

# %%
#env = gym.make('LunarLander-v2')
agent_h.epsilon = 0
total_reward = 0
state = env.reset()
for t in range(t_max):
    action = agent_h.get_action([state])
    next_state, reward, done, _ = env.step(action[0])
    env.render()
    total_reward += reward
    state = next_state
    if done:
        break
print(total_reward)
# Out:
# -165.60246600712213

# %%
class SDQN:
    def __init__(self, state_dim, action_dim, gamma=0.993, lr=1e-3, batch_size=128, epsilon_decrease=0.01, epsilon_min=0.03):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.q_function = Qfunction(self.state_dim, self.action_dim)
        self.q_function_ = Qfunction(self.state_dim, self.action_dim)
        for target_param in self.q_function_.parameters():
            target_param.data.copy_(target_param.data*0)
        self.gamma = gamma
        self.batch_size = batch_size
        self.epsilon = 1
        self.epsilon_decrease = epsilon_decrease
        self.epsilon_min = epsilon_min
        self.memory = []
        self.memory_lim = 150000
        self.optimzaer = torch.optim.Adam(self.q_function.parameters(), lr=lr)

    def get_action(self, state, target= False):
        if(target):
            q_values = self.q_function_(torch.FloatTensor(state))
        else:
            q_values = self.q_function(torch.FloatTensor(state))
        argmax_action = torch.argmax(q_values,dim=-1)
        probs = self.epsilon * np.ones((argmax_action.shape[0],self.action_dim)) / self.action_dim
        probs[np.arange(argmax_action.shape[0]),argmax_action] += 1 - self.epsilon
        action = np.ones(q_values.shape[0], dtype=np.int32)
        for sample in range(q_values.shape[0]):
            action[sample] = np.random.choice(np.arange(self.action_dim), p=probs[sample,:])
        return action
    
    def fit(self, state, action, reward, done, next_state, tau):
        self.memory.append([state, action, reward, int(done), next_state])
        if(len(self.memory)>self.memory_lim):
            self.memory = self.memory[int(self.memory_lim*0.05):]
            self.memory = random.sample(self.memory, int(self.memory_lim*0.9))
            print('clear memory')
        if len(self.memory) > self.batch_size:
            batch = random.sample(self.memory, self.batch_size)
            states, actions, rewards, dones, next_states = map(torch.tensor, list(zip(*batch)))
    
            targets = rewards + self.gamma * (1 - dones) * torch.max(self.q_function_(next_states), dim=1).values
            q_values = self.q_function(states)[torch.arange(self.batch_size), actions]
            
            loss = torch.mean((q_values - targets.detach()) ** 2)
            loss.backward()
            self.optimzaer.step()
            self.optimzaer.zero_grad()
            
            self.soft_update(self.q_function,self.q_function_, tau)
            
            if self.epsilon > self.epsilon_min:
                self.epsilon -= self.epsilon_decrease
                
    def soft_update(self, local_model, target_model, tau):
        """Soft update model parameters.
        θ_target = τ*θ_local + (1 - τ)*θ_target

        Params
        ======
            local_model (PyTorch model): weights will be copied from
            target_model (PyTorch model): weights will be copied to
            tau (float): interpolation parameter 
        """
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau*local_param.data + (1.0-tau)*target_param.data)

# %%
# %%time
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

episode_n = 2000
t_max = 1000
do_clear = True

agent_s = SDQN(state_dim, action_dim,epsilon_decrease=0.03/episode_n)
hist_s = []
hist_s_v = []
hist_s_v_disc = []
hist_s_v_ = []
hist_s_v_disc_ = []

for episode in range(episode_n):
    total_reward = 0

    state = env.reset()
    for t in range(t_max):
        action = agent_s.get_action([state])
        next_state, reward, done, _ = env.step(action[0])

        total_reward += reward
        agent_s.fit(state, int(action), reward, done, next_state,tau = 0.005)

        state = next_state

        if done:
            break
    
    hist_s.append(total_reward)
    
    #validate
    if(episode%10 == 0):
        eps = agent_s.epsilon
        agent_s.epsilon = 0
        total_reward = 0
        total_reward_disc = 0
        rew_mult = 1
        state = env.reset()
        for t in range(t_max):
            action = agent_s.get_action([state], True)
            next_state, reward, done, _ = env.step(action[0])

            total_reward += reward
            
            total_reward_disc += rew_mult*reward
            rew_mult *= agent_s.gamma

            state = next_state

            if done:
                break
        agent_s.epsilon = eps
        
        hist_s_v_.append(total_reward)
        hist_s_v_disc_.append(total_reward_disc)
        
    
    if(episode%10 == 0):
        eps = agent_s.epsilon
        agent_s.epsilon = 0
        total_reward = 0
        total_reward_disc = 0
        rew_mult = 1
        state = env.reset()
        for t in range(t_max):
            action = agent_s.get_action([state], False)
            next_state, reward, done, _ = env.step(action[0])

            total_reward += reward
            
            total_reward_disc += rew_mult*reward
            rew_mult *= agent_s.gamma

            state = next_state

            if done:
                break
        agent_s.epsilon = eps
        
        hist_s_v.append(total_reward)
        hist_s_v_disc.append(total_reward_disc)
        
    if(np.mean(hist_s_v[-10:])>220 and np.mean(hist_s_v_[-10:])>220):
        break
    if(np.mean(hist_s_v[-10:])>240 or np.mean(hist_s_v_[-10:])>240):
        break

    print(f'episode: {episode}, \
rew: {round(np.mean(hist_s[-100:]),2)}, \
v_: {round(np.mean(hist_s_v_[-10:]),2)}, \
v_disc_: {round(np.mean(hist_s_v_disc_[-10:]),2)}, \
v: {round(np.mean(hist_s_v[-10:]),2)}, \
v_disc: {round(np.mean(hist_s_v_disc[-10:]),2)}, \
epsilon: {round(agent_s.epsilon,2)}, \
mem: {len(agent_s.memory)}')
# Out:
# C:\Users\boh-b\AppData\Local\Temp\ipykernel_32636\2198439829.py:22: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ..\torch\csrc\utils\tensor_new.cpp:204.)
#   q_values = self.q_function(torch.FloatTensor(state))
# episode: 0, rew: 38.16, v_: -139.24, v_disc_: -89.7, v: -102.18, v_disc: -76.23, epsilon: 1, mem: 91
# episode: 1, rew: -79.23, v_: -139.24, v_disc_: -89.7, v: -102.18, v_disc: -76.23, epsilon: 1.0, mem: 180
# episode: 2, rew: -82.5, v_: -139.24, v_disc_: -89.7, v: -102.18, v_disc: -76.23, epsilon: 1.0, mem: 253
# episode: 3, rew: -92.47, v_: -139.24, v_disc_: -89.7, v: -102.18, v_disc: -76.23, epsilon: 1.0, mem: 352
# episode: 4, rew: -114.04, v_: -139.24, v_disc_: -89.7, v: -102.18, v_disc: -76.23, epsilon: 0.99, mem: 470
# episode: 5, rew: -115.96, v_: -139.24, v_disc_: -89.7, v: -102.18, v_disc: -76.23, epsilon: 0.99, mem: 577
# episode: 6, rew: -117.2, v_: -139.24, v_disc_: -89.7, v: -102.18, v_disc: -76.23, epsilon: 0.99, mem: 644
# episode: 7, rew: -113.37, v_: -139.24, v_disc_: -89.7, v: -102.18, v_disc: -76.23, epsilon: 0.99, mem: 747
# episode: 8, rew: -111.42, v_: -139.24, v_disc_: -89.7, v: -102.18, v_disc: -76.23, epsilon: 0.99, mem: 824
# episode: 9, rew: -123.03, v_: -139.24, v_disc_: -89.7, v: -102.18, v_disc: -76.23, epsilon: 0.99, mem: 911
# episode: 10, rew: -119.88, v_: -434.45, v_disc_: -210.3, v: -400.75, v_disc: -196.29, epsilon: 0.99, mem: 1001
# episode: 11, rew: -118.15, v_: -434.45, v_disc_: -210.3, v: -400.75, v_disc: -196.29, epsilon: 0.99, mem: 1098
# episode: 12, rew: -132.57, v_: -434.45, v_disc_: -210.3, v: -400.75, v_disc: -196.29, epsilon: 0.98, mem: 1193
# episode: 13, rew: -126.88, v_: -434.45, v_disc_: -210.3, v: -400.75, v_disc: -196.29, epsilon: 0.98, mem: 1306
# episode: 14, rew: -122.63, v_: -434.45, v_disc_: -210.3, v: -400.75, v_disc: -196.29, epsilon: 0.98, mem: 1377
# episode: 15, rew: -145.3, v_: -434.45, v_disc_: -210.3, v: -400.75, v_disc: -196.29, epsilon: 0.98, mem: 1484
# episode: 16, rew: -141.59, v_: -434.45, v_disc_: -210.3, v: -400.75, v_disc: -196.29, epsilon: 0.98, mem: 1551
# episode: 17, rew: -144.04, v_: -434.45, v_disc_: -210.3, v: -400.75, v_disc: -196.29, epsilon: 0.98, mem: 1638
# episode: 18, rew: -151.47, v_: -434.45, v_disc_: -210.3, v: -400.75, v_disc: -196.29, epsilon: 0.98, mem: 1778
# episode: 19, rew: -154.45, v_: -434.45, v_disc_: -210.3, v: -400.75, v_disc: -196.29, epsilon: 0.97, mem: 1844
# episode: 20, rew: -163.64, v_: -397.47, v_disc_: -198.6, v: -456.58, v_disc: -242.52, epsilon: 0.97, mem: 1927
# episode: 21, rew: -161.35, v_: -397.47, v_disc_: -198.6, v: -456.58, v_disc: -242.52, epsilon: 0.97, mem: 2045
# episode: 22, rew: -158.02, v_: -397.47, v_disc_: -198.6, v: -456.58, v_disc: -242.52, epsilon: 0.97, mem: 2124
# episode: 23, rew: -156.58, v_: -397.47, v_disc_: -198.6, v: -456.58, v_disc: -242.52, epsilon: 0.97, mem: 2228
# episode: 24, rew: -153.66, v_: -397.47, v_disc_: -198.6, v: -456.58, v_disc: -242.52, epsilon: 0.97, mem: 2317
# episode: 25, rew: -150.51, v_: -397.47, v_disc_: -198.6, v: -456.58, v_disc: -242.52, epsilon: 0.97, mem: 2398
# episode: 26, rew: -148.83, v_: -397.47, v_disc_: -198.6, v: -456.58, v_disc: -242.52, epsilon: 0.96, mem: 2473
# episode: 27, rew: -144.98, v_: -397.47, v_disc_: -198.6, v: -456.58, v_disc: -242.52, epsilon: 0.96, mem: 2593
# episode: 28, rew: -147.83, v_: -397.47, v_disc_: -198.6, v: -456.58, v_disc: -242.52, epsilon: 0.96, mem: 2696
# episode: 29, rew: -145.76, v_: -397.47, v_disc_: -198.6, v: -456.58, v_disc: -242.52, epsilon: 0.96, mem: 2768
# episode: 30, rew: -145.89, v_: -326.46, v_disc_: -164.11, v: -501.48, v_disc: -295.79, epsilon: 0.96, mem: 2869
# episode: 31, rew: -144.19, v_: -326.46, v_disc_: -164.11, v: -501.48, v_disc: -295.79, epsilon: 0.96, mem: 2934
# episode: 32, rew: -148.23, v_: -326.46, v_disc_: -164.11, v: -501.48, v_disc: -295.79, epsilon: 0.96, mem: 3042
# episode: 33, rew: -148.68, v_: -326.46, v_disc_: -164.11, v: -501.48, v_disc: -295.79, epsilon: 0.96, mem: 3127
# episode: 34, rew: -149.89, v_: -326.46, v_disc_: -164.11, v: -501.48, v_disc: -295.79, epsilon: 0.95, mem: 3259
# episode: 35, rew: -149.5, v_: -326.46, v_disc_: -164.11, v: -501.48, v_disc: -295.79, epsilon: 0.95, mem: 3354
# episode: 36, rew: -150.29, v_: -326.46, v_disc_: -164.11, v: -501.48, v_disc: -295.79, epsilon: 0.95, mem: 3443
# episode: 37, rew: -149.15, v_: -326.46, v_disc_: -164.11, v: -501.48, v_disc: -295.79, epsilon: 0.95, mem: 3544
# episode: 38, rew: -149.11, v_: -326.46, v_disc_: -164.11, v: -501.48, v_disc: -295.79, epsilon: 0.95, mem: 
v_: 204.97, v_disc_: 62.62, v: -126.21, v_disc: 13.19, epsilon: 0.03, mem: 147069
# episode: 822, rew: 186.9, v_: 204.97, v_disc_: 62.62, v: -126.21, v_disc: 13.19, epsilon: 0.03, mem: 147419
# episode: 823, rew: 186.68, v_: 204.97, v_disc_: 62.62, v: -126.21, v_disc: 13.19, epsilon: 0.03, mem: 147748
# episode: 824, rew: 186.58, v_: 204.97, v_disc_: 62.62, v: -126.21, v_disc: 13.19, epsilon: 0.03, mem: 148031
# episode: 825, rew: 188.91, v_: 204.97, v_disc_: 62.62, v: -126.21, v_disc: 13.19, epsilon: 0.03, mem: 148548
# episode: 826, rew: 185.32, v_: 204.97, v_disc_: 62.62, v: -126.21, v_disc: 13.19, epsilon: 0.03, mem: 148930
# episode: 827, rew: 188.69, v_: 204.97, v_disc_: 62.62, v: -126.21, v_disc: 13.19, epsilon: 0.03, mem: 149281
# episode: 828, rew: 192.88, v_: 204.97, v_disc_: 62.62, v: -126.21, v_disc: 13.19, epsilon: 0.03, mem: 149560
# episode: 829, rew: 193.79, v_: 204.97, v_disc_: 62.62, v: -126.21, v_disc: 13.19, epsilon: 0.03, mem: 149884
# clear memory
# episode: 830, rew: 193.23, v_: 223.5, v_disc_: 66.11, v: -89.54, v_disc: 26.59, epsilon: 0.03, mem: 135189
# episode: 831, rew: 191.9, v_: 223.5, v_disc_: 66.11, v: -89.54, v_disc: 26.59, epsilon: 0.03, mem: 136189
# episode: 832, rew: 194.15, v_: 223.5, v_disc_: 66.11, v: -89.54, v_disc: 26.59, epsilon: 0.03, mem: 136468
# episode: 833, rew: 197.51, v_: 223.5, v_disc_: 66.11, v: -89.54, v_disc: 26.59, epsilon: 0.03, mem: 136836
# episode: 834, rew: 192.28, v_: 223.5, v_disc_: 66.11, v: -89.54, v_disc: 26.59, epsilon: 0.03, mem: 136930
# episode: 835, rew: 192.37, v_: 223.5, v_disc_: 66.11, v: -89.54, v_disc: 26.59, epsilon: 0.03, mem: 137283
# episode: 836, rew: 191.59, v_: 223.5, v_disc_: 66.11, v: -89.54, v_disc: 26.59, epsilon: 0.03, mem: 138283
# episode: 837, rew: 194.8, v_: 223.5, v_disc_: 66.11, v: -89.54, v_disc: 26.59, epsilon: 0.03, mem: 138770
# episode: 838, rew: 197.08, v_: 223.5, v_disc_: 66.11, v: -89.54, v_disc: 26.59, epsilon: 0.03, mem: 139229
# episode: 839, rew: 196.89, v_: 223.5, v_disc_: 66.11, v: -89.54, v_disc: 26.59, epsilon: 0.03, mem: 139502
# episode: 840, rew: 194.89, v_: 226.58, v_disc_: 68.61, v: -103.12, v_disc: 21.86, epsilon: 0.03, mem: 139629
# episode: 841, rew: 194.98, v_: 226.58, v_disc_: 68.61, v: -103.12, v_disc: 21.86, epsilon: 0.03, mem: 140086
# episode: 842, rew: 195.05, v_: 226.58, v_disc_: 68.61, v: -103.12, v_disc: 21.86, epsilon: 0.03, mem: 140570
# episode: 843, rew: 192.01, v_: 226.58, v_disc_: 68.61, v: -103.12, v_disc: 21.86, epsilon: 0.03, mem: 141195
# episode: 844, rew: 196.45, v_: 226.58, v_disc_: 68.61, v: -103.12, v_disc: 21.86, epsilon: 0.03, mem: 141657
# episode: 845, rew: 198.1, v_: 226.58, v_disc_: 68.61, v: -103.12, v_disc: 21.86, epsilon: 0.03, mem: 142310
# episode: 846, rew: 196.98, v_: 226.58, v_disc_: 68.61, v: -103.12, v_disc: 21.86, epsilon: 0.03, mem: 143310
# episode: 847, rew: 196.82, v_: 226.58, v_disc_: 68.61, v: -103.12, v_disc: 21.86, epsilon: 0.03, mem: 144309
# episode: 848, rew: 196.44, v_: 226.58, v_disc_: 68.61, v: -103.12, v_disc: 21.86, epsilon: 0.03, mem: 144809
# episode: 849, rew: 195.83, v_: 226.58, v_disc_: 68.61, v: -103.12, v_disc: 21.86, epsilon: 0.03, mem: 145181
# episode: 850, rew: 195.75, v_: 234.33, v_disc_: 70.05, v: -71.76, v_disc: 27.45, epsilon: 0.03, mem: 145715
# episode: 851, rew: 195.92, v_: 234.33, v_disc_: 70.05, v: -71.76, v_disc: 27.45, epsilon: 0.03, mem: 146049
# episode: 852, rew: 195.42, v_: 234.33, v_disc_: 70.05, v: -71.76, v_disc: 27.45, epsilon: 0.03, mem: 146396
# episode: 853, rew: 196.01, v_: 234.33, v_disc_: 70.05, v: -71.76, v_disc: 27.45, epsilon: 0.03, mem: 146707
# episode: 854, rew: 196.08, v_: 234.33, v_disc_: 70.05, v: -71.76, v_disc: 27.45, epsilon: 0.03, mem: 147176
# episode: 855, rew: 196.53, v_: 234.33, v_disc_: 70.05, v: -71.76, v_disc: 27.45, epsilon: 0.03, mem: 147542
# episode: 856, rew: 196.98, v_: 234.33, v_disc_: 70.05, v: -71.76, v_disc: 27.45, epsilon: 0.03, mem: 147939
# episode: 857, rew: 197.02, v_: 234.33, v_disc_: 70.05, v: -71.76, v_disc: 27.45, epsilon: 0.03, mem: 148176
# episode: 858, rew: 199.5, v_: 234.33, v_disc_: 70.05, v: -71.76, v_disc: 27.45, epsilon: 0.03, mem: 148827
# episode: 859, rew: 199.33, v_: 234.33, v_disc_: 70.05, v: -71.76, v_disc: 27.45, epsilon: 0.03, mem: 149334
# CPU times: total: 1h 46min 45s
# Wall time: 22min 31s

# %%
plt.grid(True)
plt.plot([i for i in range(0,len(hist_s[::10])*10,10)],np.convolve(hist_s[::10],np.ones(10)/10,mode='same'))
plt.plot([i for i in range(0,len(hist_s[::10])*10,10)],np.convolve(hist_s_v,np.ones(10)/10,mode='same'),label='hist_s_v')
plt.plot([i for i in range(0,len(hist_s[::10])*10,10)],np.convolve(hist_s_v_disc,np.ones(10)/10,mode='same'),label='hist_s_v_disc')
plt.plot([i for i in range(0,len(hist_s[::10])*10,10)],np.convolve(hist_s_v_,np.ones(10)/10,mode='same'),label='hist_s_v_')
plt.plot([i for i in range(0,len(hist_s[::10])*10,10)],np.convolve(hist_s_v_disc_,np.ones(10)/10,mode='same'),label='hist_s_v_disc_')
plt.xlabel('episodes')
plt.ylabel('mean reward (10 episodes)')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig('s_final.png',dpi = 300, bbox_inches='tight', facecolor='w')

# %%
for target_param, local_param in zip(agent_s.q_function_.parameters(), agent_s.q_function.parameters()):
    print(torch.max((target_param-local_param)/target_param),torch.max((target_param-local_param)/local_param))
# Out:
# tensor(0.6526, grad_fn=<MaxBackward1>) tensor(1.8782, grad_fn=<MaxBackward1>)
# tensor(0.1711, grad_fn=<MaxBackward1>) tensor(0.2064, grad_fn=<MaxBackward1>)
# tensor(31.8134, grad_fn=<MaxBackward1>) tensor(1.5412, grad_fn=<MaxBackward1>)
# tensor(0.2741, grad_fn=<MaxBackward1>) tensor(0.3776, grad_fn=<MaxBackward1>)
# tensor(0.0166, grad_fn=<MaxBackward1>) tensor(0.0169, grad_fn=<MaxBackward1>)
# tensor(-0.0004, grad_fn=<MaxBackward1>) tensor(-0.0004, grad_fn=<MaxBackward1>)

# %%
#env = gym.make('LunarLander-v2')
agent_s.epsilon = 0
total_reward = 0
state = env.reset()
for t in range(t_max):
    action = agent_s.get_action([state],True)
    next_state, reward, done, _ = env.step(action[0])
    env.render()
    total_reward += reward
    state = next_state
    if done:
        break
print(total_reward)
# Out:
# -44.65895993981232

# %%
env = gym.make('LunarLander-v2')

# %%
class DDQN:
    def __init__(self, state_dim, action_dim, gamma=0.993, lr=1e-3, batch_size=128, epsilon_decrease=0.01, epsilon_min=0.03):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.q_function = Qfunction(self.state_dim, self.action_dim)
        self.q_function_ = Qfunction(self.state_dim, self.action_dim)
        for target_param in self.q_function_.parameters():
            target_param.data.copy_(target_param.data*0)
        self.gamma = gamma
        self.batch_size = batch_size
        self.epsilon = 1
        self.epsilon_decrease = epsilon_decrease
        self.epsilon_min = epsilon_min
        self.memory = []
        self.memory_lim = 150000
        self.optimzaer = torch.optim.Adam(self.q_function.parameters(), lr=lr)

    def get_action(self, state, target = False):
        if(target):
            q_values = self.q_function_(torch.FloatTensor(state))
        else:
            q_values = self.q_function(torch.FloatTensor(state))
        argmax_action = torch.argmax(q_values,dim=-1)
        probs = self.epsilon * np.ones((argmax_action.shape[0],self.action_dim)) / self.action_dim
        probs[np.arange(argmax_action.shape[0]),argmax_action] += 1 - self.epsilon
        action = np.ones(q_values.shape[0], dtype=np.int32)
        for sample in range(q_values.shape[0]):
            action[sample] = np.random.choice(np.arange(self.action_dim), p=probs[sample,:])
        return action
    
    def fit(self, state, action, reward, done, next_state, tau):
        self.memory.append([state, action, reward, int(done), next_state])
        if(len(self.memory)>self.memory_lim):
            self.memory = self.memory[int(self.memory_lim*0.05):]
            self.memory = random.sample(self.memory, int(self.memory_lim*0.9))
            print('clear memory')
        if len(self.memory) > self.batch_size:
            batch = random.sample(self.memory, self.batch_size)
            states, actions, rewards, dones, next_states = map(torch.tensor, list(zip(*batch)))
            targets = rewards + self.gamma * (1 - dones) * (self.q_function(next_states)[np.arange(self.batch_size),torch.argmax(self.q_function_(next_states), dim=1)])
            q_values = self.q_function(states)[torch.arange(self.batch_size), actions]
            
            loss = torch.mean((q_values - targets.detach()) ** 2)
            loss.backward()
            self.optimzaer.step()
            self.optimzaer.zero_grad()
            
            self.soft_update(self.q_function,self.q_function_, tau)
            
            if self.epsilon > self.epsilon_min:
                self.epsilon -= self.epsilon_decrease
                
    def soft_update(self, local_model, target_model, tau):
        """Soft update model parameters.
        θ_target = τ*θ_local + (1 - τ)*θ_target

        Params
        ======
            local_model (PyTorch model): weights will be copied from
            target_model (PyTorch model): weights will be copied to
            tau (float): interpolation parameter 
        """
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau*local_param.data + (1.0-tau)*target_param.data)

# %%
# %%time
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

episode_n = 2000
t_max = 1000
do_clear = True

agent_d = DDQN(state_dim, action_dim,epsilon_decrease=0.03/episode_n)
hist_d = []
hist_d_v = []
hist_d_v_disc = []
hist_d_v_ = []
hist_d_v_disc_ = []

for episode in range(episode_n):
    total_reward = 0

    state = env.reset()
    for t in range(t_max):
        action = agent_d.get_action([state])
        next_state, reward, done, _ = env.step(action[0])

        total_reward += reward
        agent_d.fit(state, int(action), reward, done, next_state,tau = 0.005)

        state = next_state

        if done:
            break
    
    hist_d.append(total_reward)
    
    #validate
    if(episode%10 == 0):
        eps = agent_d.epsilon
        agent_d.epsilon = 0
        total_reward = 0
        total_reward_disc = 0
        rew_mult = 1
        state = env.reset()
        for t in range(t_max):
            action = agent_d.get_action([state], True)
            next_state, reward, done, _ = env.step(action[0])

            total_reward += reward
            
            total_reward_disc += rew_mult*reward
            rew_mult *= agent_d.gamma

            state = next_state

            if done:
                break
        agent_d.epsilon = eps
        
        hist_d_v_.append(total_reward)
        hist_d_v_disc_.append(total_reward_disc)
        
    
    if(episode%10 == 0):
        eps = agent_d.epsilon
        agent_d.epsilon = 0
        total_reward = 0
        total_reward_disc = 0
        rew_mult = 1
        state = env.reset()
        for t in range(t_max):
            action = agent_d.get_action([state], False)
            next_state, reward, done, _ = env.step(action[0])

            total_reward += reward
            
            total_reward_disc += rew_mult*reward
            rew_mult *= agent_d.gamma

            state = next_state

            if done:
                break
        agent_d.epsilon = eps
        
        hist_d_v.append(total_reward)
        hist_d_v_disc.append(total_reward_disc)
        
    if(np.mean(hist_d_v[-10:])>220 and np.mean(hist_d_v_[-10:])>220):
        break
    if(np.mean(hist_d_v[-10:])>240 or np.mean(hist_d_v_[-10:])>240):
        break

    print(f'episode: {episode}, \
rew: {round(np.mean(hist_d[-100:]),2)}, \
v_: {round(np.mean(hist_d_v_[-10:]),2)}, \
v_disc_: {round(np.mean(hist_d_v_disc_[-10:]),2)}, \
v: {round(np.mean(hist_d_v[-10:]),2)}, \
v_disc: {round(np.mean(hist_d_v_disc[-10:]),2)}, \
epsilon: {round(agent_d.epsilon,2)}, \
mem: {len(agent_d.memory)}')
# Out:
# episode: 0, rew: -225.68, v_: -166.2, v_disc_: -115.53, v: -481.1, v_disc: -339.48, epsilon: 1, mem: 112
# episode: 1, rew: -211.94, v_: -166.2, v_disc_: -115.53, v: -481.1, v_disc: -339.48, epsilon: 1.0, mem: 185
# episode: 2, rew: -193.55, v_: -166.2, v_disc_: -115.53, v: -481.1, v_disc: -339.48, epsilon: 1.0, mem: 257
# episode: 3, rew: -259.98, v_: -166.2, v_disc_: -115.53, v: -481.1, v_disc: -339.48, epsilon: 1.0, mem: 361
# episode: 4, rew: -228.18, v_: -166.2, v_disc_: -115.53, v: -481.1, v_disc: -339.48, epsilon: 1.0, mem: 434
# episode: 5, rew: -209.91, v_: -166.2, v_disc_: -115.53, v: -481.1, v_disc: -339.48, epsilon: 0.99, mem: 519
# episode: 6, rew: -203.1, v_: -166.2, v_disc_: -115.53, v: -481.1, v_disc: -339.48, epsilon: 0.99, mem: 626
# episode: 7, rew: -196.28, v_: -166.2, v_disc_: -115.53, v: -481.1, v_disc: -339.48, epsilon: 0.99, mem: 708
# episode: 8, rew: -188.65, v_: -166.2, v_disc_: -115.53, v: -481.1, v_disc: -339.48, epsilon: 0.99, mem: 822
# episode: 9, rew: -188.29, v_: -166.2, v_disc_: -115.53, v: -481.1, v_disc: -339.48, epsilon: 0.99, mem: 948
# episode: 10, rew: -178.85, v_: -479.12, v_disc_: -304.74, v: -495.98, v_disc: -339.66, epsilon: 0.99, mem: 1012
# episode: 11, rew: -199.52, v_: -479.12, v_disc_: -304.74, v: -495.98, v_disc: -339.66, epsilon: 0.99, mem: 1124
# episode: 12, rew: -202.5, v_: -479.12, v_disc_: -304.74, v: -495.98, v_disc: -339.66, epsilon: 0.98, mem: 1217
# episode: 13, rew: -194.57, v_: -479.12, v_disc_: -304.74, v: -495.98, v_disc: -339.66, epsilon: 0.98, mem: 1291
# episode: 14, rew: -196.22, v_: -479.12, v_disc_: -304.74, v: -495.98, v_disc: -339.66, epsilon: 0.98, mem: 1350
# episode: 15, rew: -193.27, v_: -479.12, v_disc_: -304.74, v: -495.98, v_disc: -339.66, epsilon: 0.98, mem: 1449
# episode: 16, rew: -187.91, v_: -479.12, v_disc_: -304.74, v: -495.98, v_disc: -339.66, epsilon: 0.98, mem: 1557
# episode: 17, rew: -185.16, v_: -479.12, v_disc_: -304.74, v: -495.98, v_disc: -339.66, epsilon: 0.98, mem: 1623
# episode: 18, rew: -184.67, v_: -479.12, v_disc_: -304.74, v: -495.98, v_disc: -339.66, epsilon: 0.98, mem: 1730
# episode: 19, rew: -185.74, v_: -479.12, v_disc_: -304.74, v: -495.98, v_disc: -339.66, epsilon: 0.97, mem: 1833
# episode: 20, rew: -184.94, v_: -347.11, v_disc_: -203.74, v: -340.78, v_disc: -229.33, epsilon: 0.97, mem: 1949
# episode: 21, rew: -180.52, v_: -347.11, v_disc_: -203.74, v: -340.78, v_disc: -229.33, epsilon: 0.97, mem: 2113
# episode: 22, rew: -185.51, v_: -347.11, v_disc_: -203.74, v: -340.78, v_disc: -229.33, epsilon: 0.97, mem: 2185
# episode: 23, rew: -184.07, v_: -347.11, v_disc_: -203.74, v: -340.78, v_disc: -229.33, epsilon: 0.97, mem: 2274
# episode: 24, rew: -186.1, v_: -347.11, v_disc_: -203.74, v: -340.78, v_disc: -229.33, epsilon: 0.97, mem: 2351
# episode: 25, rew: -191.67, v_: -347.11, v_disc_: -203.74, v: -340.78, v_disc: -229.33, epsilon: 0.97, mem: 2446
# episode: 26, rew: -193.15, v_: -347.11, v_disc_: -203.74, v: -340.78, v_disc: -229.33, epsilon: 0.96, mem: 2530
# episode: 27, rew: -186.19, v_: -347.11, v_disc_: -203.74, v: -340.78, v_disc: -229.33, epsilon: 0.96, mem: 2621
# episode: 28, rew: -183.12, v_: -347.11, v_disc_: -203.74, v: -340.78, v_disc: -229.33, epsilon: 0.96, mem: 2708
# episode: 29, rew: -181.5, v_: -347.11, v_disc_: -203.74, v: -340.78, v_disc: -229.33, epsilon: 0.96, mem: 2772
# episode: 30, rew: -178.75, v_: -299.99, v_disc_: -149.9, v: -312.05, v_disc: -187.1, epsilon: 0.96, mem: 2834
# episode: 31, rew: -177.26, v_: -299.99, v_disc_: -149.9, v: -312.05, v_disc: -187.1, epsilon: 0.96, mem: 2946
# episode: 32, rew: -174.62, v_: -299.99, v_disc_: -149.9, v: -312.05, v_disc: -187.1, epsilon: 0
v_: 153.97, v_disc_: 50.47, v: 198.12, v_disc: 61.26, epsilon: 0.03, mem: 149378
# episode: 769, rew: 222.11, v_: 153.97, v_disc_: 50.47, v: 198.12, v_disc: 61.26, epsilon: 0.03, mem: 149729
# clear memory
# episode: 770, rew: 222.55, v_: 154.04, v_disc_: 51.23, v: 195.85, v_disc: 62.04, epsilon: 0.03, mem: 135014
# episode: 771, rew: 222.64, v_: 154.04, v_disc_: 51.23, v: 195.85, v_disc: 62.04, epsilon: 0.03, mem: 135257
# episode: 772, rew: 222.7, v_: 154.04, v_disc_: 51.23, v: 195.85, v_disc: 62.04, epsilon: 0.03, mem: 135481
# episode: 773, rew: 223.84, v_: 154.04, v_disc_: 51.23, v: 195.85, v_disc: 62.04, epsilon: 0.03, mem: 135800
# episode: 774, rew: 223.79, v_: 154.04, v_disc_: 51.23, v: 195.85, v_disc: 62.04, epsilon: 0.03, mem: 136109
# episode: 775, rew: 223.62, v_: 154.04, v_disc_: 51.23, v: 195.85, v_disc: 62.04, epsilon: 0.03, mem: 136682
# episode: 776, rew: 224.0, v_: 154.04, v_disc_: 51.23, v: 195.85, v_disc: 62.04, epsilon: 0.03, mem: 137040
# episode: 777, rew: 223.91, v_: 154.04, v_disc_: 51.23, v: 195.85, v_disc: 62.04, epsilon: 0.03, mem: 137258
# episode: 778, rew: 223.34, v_: 154.04, v_disc_: 51.23, v: 195.85, v_disc: 62.04, epsilon: 0.03, mem: 137663
# episode: 779, rew: 223.54, v_: 154.04, v_disc_: 51.23, v: 195.85, v_disc: 62.04, epsilon: 0.03, mem: 137872
# episode: 780, rew: 223.73, v_: 158.26, v_disc_: 56.6, v: 100.02, v_disc: 60.94, epsilon: 0.03, mem: 138265
# episode: 781, rew: 224.28, v_: 158.26, v_disc_: 56.6, v: 100.02, v_disc: 60.94, epsilon: 0.03, mem: 138600
# episode: 782, rew: 224.81, v_: 158.26, v_disc_: 56.6, v: 100.02, v_disc: 60.94, epsilon: 0.03, mem: 139373
# episode: 783, rew: 222.26, v_: 158.26, v_disc_: 56.6, v: 100.02, v_disc: 60.94, epsilon: 0.03, mem: 139629
# episode: 784, rew: 222.87, v_: 158.26, v_disc_: 56.6, v: 100.02, v_disc: 60.94, epsilon: 0.03, mem: 139970
# episode: 785, rew: 222.33, v_: 158.26, v_disc_: 56.6, v: 100.02, v_disc: 60.94, epsilon: 0.03, mem: 140300
# episode: 786, rew: 222.46, v_: 158.26, v_disc_: 56.6, v: 100.02, v_disc: 60.94, epsilon: 0.03, mem: 140623
# episode: 787, rew: 221.95, v_: 158.26, v_disc_: 56.6, v: 100.02, v_disc: 60.94, epsilon: 0.03, mem: 140752
# episode: 788, rew: 222.17, v_: 158.26, v_disc_: 56.6, v: 100.02, v_disc: 60.94, epsilon: 0.03, mem: 140971
# episode: 789, rew: 223.22, v_: 158.26, v_disc_: 56.6, v: 100.02, v_disc: 60.94, epsilon: 0.03, mem: 141310
# episode: 790, rew: 226.64, v_: 170.38, v_disc_: 64.01, v: 62.43, v_disc: 56.79, epsilon: 0.03, mem: 141513
# episode: 791, rew: 226.69, v_: 170.38, v_disc_: 64.01, v: 62.43, v_disc: 56.79, epsilon: 0.03, mem: 141766
# episode: 792, rew: 226.61, v_: 170.38, v_disc_: 64.01, v: 62.43, v_disc: 56.79, epsilon: 0.03, mem: 142027
# episode: 793, rew: 226.5, v_: 170.38, v_disc_: 64.01, v: 62.43, v_disc: 56.79, epsilon: 0.03, mem: 142347
# episode: 794, rew: 226.73, v_: 170.38, v_disc_: 64.01, v: 62.43, v_disc: 56.79, epsilon: 0.03, mem: 142628
# episode: 795, rew: 226.73, v_: 170.38, v_disc_: 64.01, v: 62.43, v_disc: 56.79, epsilon: 0.03, mem: 142851
# episode: 796, rew: 231.73, v_: 170.38, v_disc_: 64.01, v: 62.43, v_disc: 56.79, epsilon: 0.03, mem: 143103
# episode: 797, rew: 231.23, v_: 170.38, v_disc_: 64.01, v: 62.43, v_disc: 56.79, epsilon: 0.03, mem: 143327
# episode: 798, rew: 231.4, v_: 170.38, v_disc_: 64.01, v: 62.43, v_disc: 56.79, epsilon: 0.03, mem: 143517
# episode: 799, rew: 231.77, v_: 170.38, v_disc_: 64.01, v: 62.43, v_disc: 56.79, epsilon: 0.03, mem: 143766
# episode: 800, rew: 229.63, v_: 167.73, v_disc_: 61.44, v: 59.03, v_disc: 56.49, epsilon: 0.03, mem: 143987
# episode: 801, rew: 229.44, v_: 167.73, v_disc_: 61.44, v: 59.03, v_disc: 56.49, epsilon: 0.03, mem: 144947
# episode: 802, rew: 232.72, v_: 167.73, v_disc_: 61.44, v: 59.03, v_disc: 56.49, epsilon: 0.03, mem: 145213
# episode: 803, rew: 233.28, v_: 167.73, v_disc_: 61.44, v: 59.03, v_disc: 56.49, epsilon: 0.03, mem: 145570
# episode: 804, rew: 233.26, v_: 167.73, v_disc_: 61.44, v: 59.03, v_disc: 56.49, epsilon: 0.03, mem: 145844
# episode: 805, rew: 227.71, v_: 167.73, v_disc_: 61.44, v: 59.03, v_disc: 56.49, epsilon: 0.03, mem: 146157
# episode: 806, rew: 227.47, v_: 167.73, v_disc_: 61.44, v: 59.03, v_disc: 56.49, epsilon: 0.03, mem: 146494
# episode: 807, rew: 230.53, v_: 167.73, v_disc_: 61.44, v: 59.03, v_disc: 56.49, epsilon: 0.03, mem: 146814
# episode: 808, rew: 227.34, v_: 167.73, v_disc_: 61.44, v: 59.03, v_disc: 56.49, epsilon: 0.03, mem: 147149
# episode: 809, rew: 227.57, v_: 167.73, v_disc_: 61.44, v: 59.03, v_disc: 56.49, epsilon: 0.03, mem: 147557
# episode: 810, rew: 227.46, v_: 175.02, v_disc_: 61.01, v: 59.51, v_disc: 57.33, epsilon: 0.03, mem: 148490
# episode: 811, rew: 227.25, v_: 175.02, v_disc_: 61.01, v: 59.51, v_disc: 57.33, epsilon: 0.03, mem: 148692
# episode: 812, rew: 226.9, v_: 175.02, v_disc_: 61.01, v: 59.51, v_disc: 57.33, epsilon: 0.03, mem: 149104
# episode: 813, rew: 227.37, v_: 175.02, v_disc_: 61.01, v: 59.51, v_disc: 57.33, epsilon: 0.03, mem: 149577
# clear memory
# episode: 814, rew: 227.31, v_: 175.02, v_disc_: 61.01, v: 59.51, v_disc: 57.33, epsilon: 0.03, mem: 135063
# episode: 815, rew: 225.35, v_: 175.02, v_disc_: 61.01, v: 59.51, v_disc: 57.33, epsilon: 0.03, mem: 135259
# episode: 816, rew: 224.76, v_: 175.02, v_disc_: 61.01, v: 59.51, v_disc: 57.33, epsilon: 0.03, mem: 135669
# episode: 817, rew: 224.69, v_: 175.02, v_disc_: 61.01, v: 59.51, v_disc: 57.33, epsilon: 0.03, mem: 135977
# episode: 818, rew: 224.64, v_: 175.02, v_disc_: 61.01, v: 59.51, v_disc: 57.33, epsilon: 0.03, mem: 136256
# episode: 819, rew: 224.86, v_: 175.02, v_disc_: 61.01, v: 59.51, v_disc: 57.33, epsilon: 0.03, mem: 136462
# CPU times: total: 1h 31min 47s
# Wall time: 18min 37s

# %%
plt.grid(True)
plt.plot([i for i in range(0,len(hist_d[::10])*10,10)],np.convolve(hist_d[::10],np.ones(10)/10,mode='same'))
plt.plot([i for i in range(0,len(hist_d[::10])*10,10)],np.convolve(hist_d_v,np.ones(10)/10,mode='same'),label='hist_d_v')
plt.plot([i for i in range(0,len(hist_d[::10])*10,10)],np.convolve(hist_d_v_disc,np.ones(10)/10,mode='same'),label='hist_d_v_disc')
plt.plot([i for i in range(0,len(hist_d[::10])*10,10)],np.convolve(hist_d_v_,np.ones(10)/10,mode='same'),label='hist_d_v_')
plt.plot([i for i in range(0,len(hist_d[::10])*10,10)],np.convolve(hist_d_v_disc_,np.ones(10)/10,mode='same'),label='hist_d_v_disc_')
plt.xlabel('episodes')
plt.ylabel('mean reward (10 episodes)')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig('d_final.png',dpi = 300, bbox_inches='tight', facecolor='w')

# %%
#env = gym.make('LunarLander-v2')
agent_d.epsilon = 0.1
total_reward = 0
state = env.reset()
for t in range(t_max//2):
    action = agent_d.get_action([state], True)
    next_state, reward, done, _ = env.step(action[0])
    env.render()
    total_reward += reward
    state = next_state
    if done:
        break
print(total_reward)
# Out:
# -558.2730384799879

# %%
for target_param, local_param in zip(agent_d.q_function_.parameters(), agent_d.q_function.parameters()):
    print(torch.max((target_param-local_param)/target_param),torch.max((target_param-local_param)/local_param))
# Out:
# tensor(0.9472, grad_fn=<MaxBackward1>) tensor(17.9465, grad_fn=<MaxBackward1>)
# tensor(0.2104, grad_fn=<MaxBackward1>) tensor(0.2664, grad_fn=<MaxBackward1>)
# tensor(2.2514, grad_fn=<MaxBackward1>) tensor(2.0815, grad_fn=<MaxBackward1>)
# tensor(0.7409, grad_fn=<MaxBackward1>) tensor(2.8591, grad_fn=<MaxBackward1>)
# tensor(0.0214, grad_fn=<MaxBackward1>) tensor(0.0219, grad_fn=<MaxBackward1>)
# tensor(-0.0011, grad_fn=<MaxBackward1>) tensor(-0.0011, grad_fn=<MaxBackward1>)

# %%
def picc(vx=0,vy=0,f=0,w=0,l=0,r=0):
    pic = np.zeros((300,300,3))
    pic_w = np.zeros((300,300,3))
    obs = np.zeros((300*300,8))
    for x in range(300):
        for y in range(300):
            obs[x*300+y] = np.array([-1.5+x/100,1.5-y/100,vx,vy,f,w,l,r])
    act_flat = agent_s.get_action(obs)
    actions = np.zeros((300,300),dtype=np.int32)
    for x in range(300):
        for y in range(300):
            actions[x,y] = act_flat[x*300+y]
            
    max_actions = actions
    for x in range(300):
        for y in range(300):
            if max_actions[x,y]>0:
                pic[x,y,max_actions[x,y]-1] = 1
                
    fig = plt.figure(figsize=(5,10))
    ax = plt.subplot(211)
    ax.imshow(pic_w)
    rect = patches.Rectangle((150-20, 150-15), 40, 30, angle=-f/3.14*180, linewidth=1, edgecolor='b', facecolor='b')
    arrow = patches.Arrow(150, 150,vx*100,-vy*100, width=10,  edgecolor='red', facecolor='r')
    ax.add_patch(rect)
    ax.add_patch(arrow)
    plt.subplot(212)
    plt.imshow(pic.transpose(1,0,2))
    plt.savefig(f'visual/lunalender_vx{vx}_vy{vy}_f{f}.png',dpi=300, bbox_inches='tight',facecolor='white')

# %%
vx = [-0.2, -0.1, 0, 0.1 , 0.2]
vy = [0, -0.3, -0.6]
f = [0]
for i in range(5):
    for j in range(3):
        for k in range(1):
            picc(vx[i],vy[j],f[k])

# %%
plt.grid(True)
plt.plot([i for i in range(0,len(hist_d[::10])*10,10)],np.convolve(hist_d_v_disc_,np.ones(10)/10,mode='same'),label='hist_d_v_disc_')
plt.plot([i for i in range(0,len(hist_s[::10])*10,10)],np.convolve(hist_s_v_disc_,np.ones(10)/10,mode='same'),label='hist_s_v_disc_')
plt.xlabel('episodes')
plt.ylabel('mean reward (10 episodes)')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig('d_vs_s_final_disc.png',dpi = 300, bbox_inches='tight', facecolor='w')
